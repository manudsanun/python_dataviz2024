# %% [markdown]
# <a href="https://colab.research.google.com/github/manudsanun/python_dataviz2024/blob/main/Mm_Pandas_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #ส่วนใหญ่จะใช้แบบนี้เปลี่ยนชื่อ pandas -> pd

# %% [markdown]
# ## load pandas data แบบที่ 2 (ดึงจาก google drive)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folk_df = pd.read_csv('/content/drive/MyDrive/folktales.csv')

# %%
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1    <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3    <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4    <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
# ..                                                 ...            ...     ...
# 221  <p>รายาบือราสะครองเมืองบรือดะ ทรงมีพระราชธิดาพ...  นิทานพื้นบ้าน     ไทย
# 222  <p>มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน     ไทย
# 223  <p>มีเต่าตัวหนึ่งเที่ยวหากินอยู่ตามชายป่าใกล้ท...  นิทานพื้นบ้าน     NaN
# 224  <p>นานมาแล้ว มีเทวดาอยู่องค์หนึ่งถูกพระอิศวรสา...  นิทานพื้นบ้าน    ไทย,
# 225  <p>ถ้ำเปอร์งง มีลำธารไหลลอดถ้ำออกไปสู่แม่น้ำปั...  นิทานพื้นบ้าน    ไทย,
#
#      temporal language rights                         license  \
# 0         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 1         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 4         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ..        ...      ...    ...                             ...
# 221       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 222       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 223       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 224       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 225       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri
# 0    https://www.sac.or.th/databases/folktales/folk...
# 1    https://www.sac.or.th/databases/folktales/folk...
# 2    https://www.sac.or.th/databases/folktales/folk...
# 3    https://www.sac.or.th/databases/folktales/folk...
# 4    https://www.sac.or.th/databases/folktales/folk...
# ..                                                 ...
# 221  https://www.sac.or.th/databases/folktales/folk...
# 222  https://www.sac.or.th/databases/folktales/folk...
# 223  https://www.sac.or.th/databases/folktales/folk...
# 224  https://www.sac.or.th/databases/folktales/folk...
# 225  https://www.sac.or.th/databases/folktales/folk...
#
# [226 rows x 11 columns]

# %%
import os # เกี่ยวกับการจัดการฐานของไฟล์ เช่น ไฟลนี้อยู่พาธนี้

path = '/content/drive/My Drive/dataviz_2021_data'

# %%
path_to_folktales = os.path.join(path,'/content/drive/MyDrive/folktales.csv')
print(path_to_folktales)
# Out:
# /content/drive/MyDrive/folktales.csv

# %%
folk_df = pd.read_csv(path_to_folktales) #path_to_folktales

# %%
print(folk_df)
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1    <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3    <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4    <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
# ..                                                 ...            ...     ...
# 221  <p>รายาบือราสะครองเมืองบรือดะ ทรงมีพระราชธิดาพ...  นิทานพื้นบ้าน     ไทย
# 222  <p>มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน     ไทย
# 223  <p>มีเต่าตัวหนึ่งเที่ยวหากินอยู่ตามชายป่าใกล้ท...  นิทานพื้นบ้าน     NaN
# 224  <p>นานมาแล้ว มีเทวดาอยู่องค์หนึ่งถูกพระอิศวรสา...  นิทานพื้นบ้าน    ไทย,
# 225  <p>ถ้ำเปอร์งง มีลำธารไหลลอดถ้ำออกไปสู่แม่น้ำปั...  นิทานพื้นบ้าน    ไทย,
#
#      temporal language rights                         license  \
# 0         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 1         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 4         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ..        ...      ...    ...                             ...
# 221       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 222       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 223       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 224       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 225       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri
# 0    https://www.sac.or.th/databases/folktales/folk...
# 1    https://www.sac.or.th/databases/folktales/folk...
# 2    https://www.sac.or.th/databases/folktales/folk...
# 3    https://www.sac.or.th/databases/folktales/folk...
# 4    https://www.sac.or.th/databases/folktales/folk...
# ..                                                 ...
# 221  https://www.sac.or.th/databases/folktales/folk...
# 222  https://www.sac.or.th/databases/folktales/folk...
# 223  https://www.sac.or.th/databases/folktales/folk...
# 224  https://www.sac.or.th/databases/folktales/folk...
# 225  https://www.sac.or.th/databases/folktales/folk...
#
# [226 rows x 11 columns]

# %%
folk_df.head() # โชว์แค่หัวตาราง
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0  <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 1       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 4       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                           source.uri
# 0  https://www.sac.or.th/databases/folktales/folk...
# 1  https://www.sac.or.th/databases/folktales/folk...
# 2  https://www.sac.or.th/databases/folktales/folk...
# 3  https://www.sac.or.th/databases/folktales/folk...
# 4  https://www.sac.or.th/databases/folktales/folk...

# %%
folk_df.tail() # โชว์แค่ท้ายตาราง
# Out:
#                    title             type                 creator  \
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 221  <p>รายาบือราสะครองเมืองบรือดะ ทรงมีพระราชธิดาพ...  นิทานพื้นบ้าน     ไทย
# 222  <p>มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน     ไทย
# 223  <p>มีเต่าตัวหนึ่งเที่ยวหากินอยู่ตามชายป่าใกล้ท...  นิทานพื้นบ้าน     NaN
# 224  <p>นานมาแล้ว มีเทวดาอยู่องค์หนึ่งถูกพระอิศวรสา...  นิทานพื้นบ้าน    ไทย,
# 225  <p>ถ้ำเปอร์งง มีลำธารไหลลอดถ้ำออกไปสู่แม่น้ำปั...  นิทานพื้นบ้าน    ไทย,
#
#      temporal language rights                         license  \
# 221       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 222       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 223       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 224       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 225       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri
# 221  https://www.sac.or.th/databases/folktales/folk...
# 222  https://www.sac.or.th/databases/folktales/folk...
# 223  https://www.sac.or.th/databases/folktales/folk...
# 224  https://www.sac.or.th/databases/folktales/folk...
# 225  https://www.sac.or.th/databases/folktales/folk...

# %%
folk_df.shape # (row, column)
# Out:
# (226, 11)

# %%
a = path + '/pm-18-jan-2021.csv'
print(a)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-18-jan-2021.csv

# %% [markdown]
# ## load data to memory

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %%
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
data_covid.shape
# Out:
# (12653, 10)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
folk_df['creator'][1] # ถ้าต้องการหาว่าเขาแต่งเรื่องอะไรเปลี่ยน creator -> title
# Out:
# 'พ่อใหญ่นู'

# %%
folk_df['title'][1]
# Out:
# 'ขอคำกระฮอกด่อน'

# %% [markdown]
# ### .iloc

# %%
folk_df.iloc[4,7] # [แถว, หลัก] มันคือ data แถวที่ 4 หลักที่ 7
# Out:
# 'ไทย'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# การจัดการตาราง

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = folk_df[['title','type', 'creator','subject', 'spatial']]
smaller_table # เป็นการจัดการตารางเอาแค่บางคอลัมน์
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#            subject spatial
# 0    นิทานพื้นบ้าน     ไทย
# 1    นิทานพื้นบ้าน     ไทย
# 2    นิทานพื้นบ้าน     ไทย
# 3    นิทานพื้นบ้าน     ไทย
# 4    นิทานพื้นบ้าน     ไทย
# ..             ...     ...
# 221  นิทานพื้นบ้าน     ไทย
# 222  นิทานพื้นบ้าน     ไทย
# 223  นิทานพื้นบ้าน     NaN
# 224  นิทานพื้นบ้าน    ไทย,
# 225  นิทานพื้นบ้าน    ไทย,
#
# [226 rows x 5 columns]

# %% [markdown]
# #### ตัดเฉพาะ rows ที่ต้องการ

# %% [markdown]
# ##### แบบง่าย แต่ใช้การอะไรไม่ค่อยจะได้ (มองเป็น array แล้วตัดแบบ array)

# %%
folk_df.iloc[1:5, : ]
# Out:
#                 title          type             creator  \
# 1      ขอคำกระฮอกด่อน  ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่    นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย        มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ        มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 1       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 4       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                           source.uri
# 1  https://www.sac.or.th/databases/folktales/folk...
# 2  https://www.sac.or.th/databases/folktales/folk...
# 3  https://www.sac.or.th/databases/folktales/folk...
# 4  https://www.sac.or.th/databases/folktales/folk...

# %% [markdown]
# ## Table Query

# %% [markdown]
# เลือกเฉพาะ row ที่ต้องการ ตัด column ออก

# %% [markdown]
# ### อยากได้นิทานที่เป็นมุขตลก

# %%
folk_df[folk_df['type']=='มุขตลก'] # [folk_df['type]] เป็นการชี้
# Out:
#                                           title    type              creator  \
# 3                                     บักหำน้อย  มุขตลก      สมหวัง ปานพายัพ
# 4                                    รื้อบ่อน้ำ  มุขตลก       บุญศรี เกสเสโร
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ  มุขตลก   พัชราภรณ์ เข็มเพชร
# 7                                หลวงพ่อน้องงัว  มุขตลก      สุบิน คำยางจ้อง
# 8                             หลวงพ่อกับเณรน้อย  มุขตลก  ปรางค์ทิพย์ บุญสีลา
# 9                               หัวล้านหลื่นครู  มุขตลก        ใจมา สมจันทร์
# 11            เซียงเมี่ยง ตอนหลอกเจ้าเมืองลงน้ำ  มุขตลก     เพ็ญนภา พันพินิจ
# 18                                       จับราว  มุขตลก          ชารี คำสีมา
# 19                               บักแหมบกับอีทา  มุขตลก      สุนีย์ คุณโพธิ์
# 20                             แม่เฒ่ากับลูกเขย  มุขตลก      สุนีย์ คุณโพธิ์
# 22                            หลวงพ่อกลัวผีหลอก  มุขตลก          เสาร์ จันกอ
# 23                           หลวงพ่อเข้าลอดช่อง  มุขตลก          เสาร์ จันกอ
# 24                                    ลูกหลงพ่อ  มุขตลก     จันทร์ โพธิ์ไทสง
# 25                                เจ็ดหวดเจ็ดไห  มุขตลก     จันทร์ โพธิ์ไทสง
# 27                                      บอดตาใส  มุขตลก       สดศรี  ศิริเวช
# 30                         บักขาติด กับบักตาบอด  มุขตลก  เสมียน พิบูลย์สังข์
# 33                                    หูดสามเปา  มุขตลก    ภัสดาภร อินทะบุตร
# 37                            คาดสิทุกข์บ่ฮอนมี  มุขตลก                  NaN
# 40                                      ปะติโมง  มุขตลก                  NaN
# 41                            หลวงพ่อกับน้องงัว  มุขตลก                  NaN
# 42                              เณรน้อยขี้ไก่โป  มุขตลก                  NaN
# 46              พ่อตากับลูกเขย ตอน ลูกเขยขายขี้  มุขตลก                  NaN
# 48                           พ่อตากับลูกเขยใหม่  มุขตลก                  NaN
# 53                       หลวงพ่ออยากกินจิ้งหรีด  มุขตลก                  NaN
# 55                             มะม่วงของพระราชา  มุขตลก                  NaN
# 56                                      สี่สหาย  มุขตลก                  NaN
# 64                                     ใบตองกุง  มุขตลก                  NaN
# 67                  หลวงพ่อไม้ไผ่ หลวงพ่อมะเขือ  มุขตลก                  NaN
# 73                                 ข้าวเม่าอ่อน  มุขตลก          คำเบา แทนนา
# 81                                       นายดัน  มุขตลก        กฤชกร เพชรนอก
# 90                          หลวงพ่อกินขี้ไก่โป่  มุขตลก     สมศรี ถอนภูเขียว
# 91                       หลวงพ่อม้าน้อยหลังแอ่น  มุขตลก         พรม วรรณศิริ
# 92                                  คนไหวพริบดี  มุขตลก    เหรียญ งวงชัยภูมิ
# 93                 พ่อเฒ่ากับลูกเขยกินข้าวนำกัน  มุขตลก       สุรพันธ์ บุญชู
# 97                               พ่อใหญ่หัวล้าน  มุขตลก        เลิศ ประนัดเด
# 98                             หลวงพ่อกะทอเกลือ  มุขตลก        อาคม  ปาสานัย
# 99                                      เด็กโง่  มุขตลก      เรียบ รักสมบัติ
# 108                           เซียงเมี่ยงกับหอย  มุขตลก       สุนัญญา  มะลาด
# 114                                ตะเกียงวิเศษ  มุขตลก   สวาสดิ์ ท้าวอานนท์
# 118                                   ยักษ์เกเร  มุขตลก    พิสิฐ น้อยวังคลัง
# 119                                     ยายม่วง  มุขตลก       กฤษฎา โยธายุทธ
# 121                               สามสหายสามโรค  มุขตลก                  NaN
# 122                                     หนวกพึง  มุขตลก                  NaN
# 125                               สองสหายลักไก่  มุขตลก                  NaN
# 126                              สามเกลอลักควาย  มุขตลก                  NaN
# 130                               เอาน้ำลูบท้อง  มุขตลก       ทวี มุขธระโกษา
# 132                             หนูตกถังข้าวสาร  มุขตลก       ทวี มุขธระโกษา
# 209                               ค่อยโถเอาใหม่  มุขตลก                  NaN
# 213                                     จอมคาถา  มุขตลก                  NaN
# 214                                 จังไรฉิบหาย  มุขตลก                  NaN
# 222                                   ตำราหมอดู  มุขตลก     มาลี   พันธ์วงศ์
#
#                                            description        subject spatial  \
# 3    <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4    <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
# 5    <p>มีกลุ่มเพื่อน 3 คนเป็นเพื่อนรักกัน มีแต่คนเ...  นิทานพื้นบ้าน     ไทย
# 7    <p>นานมาแล้วมีหลวงพ่อกับเณรน้อยจำวัดอยู่ในหมู่...  นิทานพื้นบ้าน     ไทย
# 8    <p>วันหนึ่ง ตอนเช้าก่อนหลวงพ่อจะออกไปบินฑบาตร ...  นิทานพื้นบ้าน    ไทย,
# 9    <p>วันหนึ่ง มีหนุ่มอ้วนกับหนุ่มผอม เป็นเพื่อนก...  นิทานพื้นบ้าน    ไทย,
# 11   <p>เซียงเมี่ยงเป็นคนที่เกลียดคร้านและก็โกหกเก่...  นิทานพื้นบ้าน     ไทย
# 18   <p>ณ กรุงเทพ บนรถเมล์ทิดจ่อยได้เข้ามากรุงเทพเพ...  นิทานพื้นบ้าน    ไทย,
# 19   <p>มีหนุ่มสาวที่รักกันมาตั้งนานแต่ด้วยทั้งสองไ...  นิทานพื้นบ้าน     ไทย
# 20   <p>วันหนึ่งมีลูกเขยกับแม่ยายคุยกันไว้ว่า</p>\n...  นิทานพื้นบ้าน     ไทย
# 22   <p>กาลครั้งหนึ่งมีหลวงพ่อกับเณรน้อยอาศัยอยู่ด้...  นิทานพื้นบ้าน    ไทย,
# 23   <p>ในวัดแห่งหนึ่งมีหลวงพ่อกับเณรน้อยอาศัยอยู่ด...  นิทานพื้นบ้าน    ไทย,
# 24   <p>มีครอบครัวอยู่ครอบครัวหนึ่งอาศัยอยู่กลางทุ่...  นิทานพื้นบ้าน     ไทย
# 25   <p>มีครอบครัวอยู่ครอบครัวนึงได้ให้กำเนิดลูกชาย...  นิทานพื้นบ้าน    ไทย,
# 27                                                 NaN  นิทานพื้นบ้าน    ไทย,
# 30   <p>ไอ้ตาบอดกับไอ้ขาติดเขาทั้งสองจะพากันไปจับนก...  นิทานพื้นบ้าน     ไทย
# 33                                                 NaN  นิทานพื้นบ้าน     ไทย
# 37                                                 NaN  นิทานพื้นบ้าน     ไทย
# 40                                                 NaN  นิทานพื้นบ้าน     ไทย
# 41                                                 NaN  นิทานพื้นบ้าน     ไทย
# 42   <p>กาลครั้งหนึ่งนานมาแล้ว มีหลวงพ่อกับเณรน้อยอ...  นิทานพื้นบ้าน     ไทย
# 46   <p>มีครอบครัวอยู่ครอบครัวหนึ่งมีลูกสาวสี่คนและ...  นิทานพื้นบ้าน    ไทย,
# 48   <p>มีครอบครัวหนึ่งมีลูกเขยใหม่ ในสมัยก่อนบ้านจ...  นิทานพื้นบ้าน    ไทย,
# 53   <p>ในลานวัดแห่งหนึ่ง มีเด็กๆ พากันมาขุดหาจิ้งห...  นิทานพื้นบ้าน    ไทย,
# 55   <p>พระราชามีมะม่วงสามฤดูอยู่ต้นหนึ่ง คนสวนขยัน...  นิทานพื้นบ้าน    ไทย,
# 56   <p>นานมาแล้วสี่สหายเป็นเพื่อนกัน คนที่หนึ่งชื่...  นิทานพื้นบ้าน    ไทย,
# 64   <p>มีอยู่วันหนึ่งพ่อตากับลูกเขยไปเก็บใบตองตึงเ...  นิทานพื้นบ้าน    ไทย,
# 67   <p>นานมาแล้วในหมู่บ้านแห่งหนึ่งมีวัดอยู่สองแห่...  นิทานพื้นบ้าน    ไทย,
# 73   <p>ช่วงเดือน พฤศจิกายน ธันวาคม ของทุกปี จะเป็น...  นิทานพื้นบ้าน    ไทย,
# 81   <p>นายดันเป็นชายตาบอดตาใส ชาวบ้านแถวนั้นพูดว่า...  นิทานพื้นบ้าน    ไทย,
# 90   <p>วัดหนึ่ง มีหลวงพ่อกับเณรน้อยสององค์ วันหนึ่...  นิทานพื้นบ้าน     ไทย
# 91   <p>วันหนึ่งหลวงพ่อบอกให้เณรไปดายหญ้าให้ เพื่อว...  นิทานพื้นบ้าน    ไทย,
# 92   <p>ตาเคนมีลูกชายอยู่คนนึง พอโตเป็นหนุ่มก็ไปชอบ...  นิทานพื้นบ้าน     ไทย
# 93   <p>วันหนึ่งพ่อตากับลูกเขยอยู่บ้านกันสองคน ก็เล...  นิทานพื้นบ้าน    ไทย,
# 97   <p>นานมาแล้ว มีคุณตาคนหนึ่งเป็นคนหัวล้าน เขามี...  นิทานพื้นบ้าน    ไทย,
# 98   <p>นานมาแล้วมีหลวงพ่อองค์หนึ่งได้รับนิมนต์ไปเท...  นิทานพื้นบ้าน    ไทย,
# 99   <p>นานมาแล้วมีเด็กผู้ชายอยู่คนหนึ่ง ไม่อยากเรี...  นิทานพื้นบ้าน    ไทย,
# 108  <p>กาลครั้งหนึ่งนานมาแล้ว มีเซียงเมี่ยงเป็นคนอ...  นิทานพื้นบ้าน    ไทย,
# 114  <p>มีชายหนุ่มคนหนึ่งเกียจคร้านไม่ทำงานทำการ แต...  นิทานพื้นบ้าน    ไทย,
# 118  <p>กาลครั้งหนึ่งนานมาแล้วมียักษ์เกเรตนหนึ่งเกเ...  นิทานพื้นบ้าน    ไทย,
# 119  <p>มียายแก่คนหนึ่งชื่อยายม่วง แกถือเสียมเดินไป...  นิทานพื้นบ้าน    ไทย,
# 121  <p>&nbsp;มีเพื่อนสหายสามคนมีอาการเป็นโรคคนละอย...  นิทานพื้นบ้าน     NaN
# 122  <p>มีครอบครัวหนึ่งมีพ่อแม่ พี่สาว น้องชาย ทำไร...  นิทานพื้นบ้าน    ไทย,
# 125  <p>&nbsp; &nbsp; มีชายหนุ่มสองคน เป็นเพื่อนรัก...  นิทานพื้นบ้าน    ไทย,
# 126  <p>&nbsp; &nbsp; &nbsp; มีชายหนุ่มสามคนเป็นเพื...  นิทานพื้นบ้าน    ไทย,
# 130  <p>ชายหนุ่มที่ไปค้างบ้านคู่หมั้นแต่ต้องสงวนท่า...  นิทานพื้นบ้าน    ไทย,
# 132  <p>เศรษฐีคนหนึ่งรักลูกสาวมากจึงอยากให้ลูกเป็นฝ...  นิทานพื้นบ้าน    ไทย,
# 209  <p>ยังมีชายหนุ่มผู้หนึ่งได้รับขวานเล่มหนึ่งเป็...  นิทานพื้นบ้าน     NaN
# 213  <p>ในหมู่บ้านแห่งหนึ่ง มีชายคนหนึ่งคิดว่าถ้าตน...  นิทานพื้นบ้าน     NaN
# 214  <p>มีครอบครัวหนึ่งมีลูกมากมายและยากจน ซ้ำร้ายล...  นิทานพื้นบ้าน     NaN
# 222  <p>มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน     ไทย
#
#      temporal language rights                         license  \
# 3         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 4         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 5         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 7         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 8         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 9         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 11        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 18        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 19        NaN      ไทย    NaN                             NaN
# 20        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 22        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 23        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 24        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 25        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 27        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 30        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 33        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 37        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 40        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 41        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 42        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 46        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 48        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 53        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 55        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 56        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 64        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 67        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 73        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 81        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 90        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 91        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 92        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 93        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 97        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 98        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 99        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 108       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 114       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 118       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 119       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 121       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 122       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 125       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 126       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 130       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 132       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 209       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 213       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 214       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 222       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri
# 3    https://www.sac.or.th/databases/folktales/folk...
# 4    https://www.sac.or.th/databases/folktales/folk...
# 5    https://www.sac.or.th/databases/folktales/folk...
# 7    https://www.sac.or.th/databases/folktales/folk...
# 8    https://www.sac.or.th/databases/folktales/folk...
# 9    https://www.sac.or.th/databases/folktales/folk...
# 11   https://www.sac.or.th/databases/folktales/folk...
# 18   https://www.sac.or.th/databases/folktales/folk...
# 19   https://www.sac.or.th/databases/folktales/folk...
# 20   https://www.sac.or.th/databases/folktales/folk...
# 22   https://www.sac.or.th/databases/folktales/folk...
# 23   https://www.sac.or.th/databases/folktales/folk...
# 24   https://www.sac.or.th/databases/folktales/folk...
# 25   https://www.sac.or.th/databases/folktales/folk...
# 27   https://www.sac.or.th/databases/folktales/folk...
# 30   https://www.sac.or.th/databases/folktales/folk...
# 33   https://www.sac.or.th/databases/folktales/folk...
# 37   https://www.sac.or.th/databases/folktales/folk...
# 40   https://www.sac.or.th/databases/folktales/folk...
# 41   https://www.sac.or.th/databases/folktales/folk...
# 42   https://www.sac.or.th/databases/folktales/folk...
# 46   https://www.sac.or.th/databases/folktales/folk...
# 48   https://www.sac.or.th/databases/folktales/folk...
# 53   https://www.sac.or.th/databases/folktales/folk...
# 55   https://www.sac.or.th/databases/folktales/folk...
# 56   https://www.sac.or.th/databases/folktales/folk...
# 64   https://www.sac.or.th/databases/folktales/folk...
# 67   https://www.sac.or.th/databases/folktales/folk...
# 73   https://www.sac.or.th/databases/folktales/folk...
# 81   https://www.sac.or.th/databases/folktales/folk...
# 90   https://www.sac.or.th/databases/folktales/folk...
# 91   https://www.sac.or.th/databases/folktales/folk...
# 92   https://www.sac.or.th/databases/folktales/folk...
# 93   https://www.sac.or.th/databases/folktales/folk...
# 97   https://www.sac.or.th/databases/folktales/folk...
# 98   https://www.sac.or.th/databases/folktales/folk...
# 99   https://www.sac.or.th/databases/folktales/folk...
# 108  https://www.sac.or.th/databases/folktales/folk...
# 114  https://www.sac.or.th/databases/folktales/folk...
# 118  https://www.sac.or.th/databases/folktales/folk...
# 119  https://www.sac.or.th/databases/folktales/folk...
# 121  https://www.sac.or.th/databases/folktales/folk...
# 122  https://www.sac.or.th/databases/folktales/folk...
# 125  https://www.sac.or.th/databases/folktales/folk...
# 126  https://www.sac.or.th/databases/folktales/folk...
# 130  https://www.sac.or.th/databases/folktales/folk...
# 132  https://www.sac.or.th/databases/folktales/folk...
# 209  https://www.sac.or.th/databases/folktales/folk...
# 213  https://www.sac.or.th/databases/folktales/folk...
# 214  https://www.sac.or.th/databases/folktales/folk...
# 222  https://www.sac.or.th/databases/folktales/folk...

# %% [markdown]
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# ### Quiz6 query data ในตาราง มาเฉพาะ 10 ตัวแรก และ 15 ตัวสุดท้าย โดยใช้ list of logic ในการ query

# %% [markdown]
#  list of logic คือ list TRUE กับ FLASE แล้วเอา list นั้นมา query

# %%
head_rows = folk_df.head(10)
tail_rows = folk_df.tail(15)
answer =  pd.concat([head_rows, tail_rows]) # pd.concat ฟังก์ชั่นที่รวมโค้ดเข้าด้วยกัน
answer
# Out:
#                                           title             type  \
# 0                                  ตาบอดคลำช้าง   นิทานประจำถิ่น
# 1                                ขอคำกระฮอกด่อน     ตำนานปรัมปรา
# 2                            ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต
# 3                                     บักหำน้อย           มุขตลก
# 4                                    รื้อบ่อน้ำ           มุขตลก
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ           มุขตลก
# 6                                 ตำนานกุดนางใย   นิทานประจำถิ่น
# 7                                หลวงพ่อน้องงัว           มุขตลก
# 8                             หลวงพ่อกับเณรน้อย           มุขตลก
# 9                               หัวล้านหลื่นครู           มุขตลก
# 211                              งูเหลือมคายพิษ  นิทานอธิบายเหตุ
# 212                             จระเข้กับจิ้งจก  นิทานอธิบายเหตุ
# 213                                     จอมคาถา           มุขตลก
# 214                                 จังไรฉิบหาย           มุขตลก
# 215                                ไชชายนายปลอก       นิทานชีวิต
# 216                              ไชชายเลือกเมีย       นิทานชีวิต
# 217                                      เณรทอง   นิทานประจำถิ่น
# 218                            ดวงอาทิตย์กับไก่  นิทานอธิบายเหตุ
# 219                     ต้นลำพูกับนิทานหิ่งห้อย  นิทานอธิบายเหตุ
# 220                                     ตาแขนปม   นิทานมหัศจรรย์
# 221                                 ตำนานมะโย่ง     ตำนานปรัมปรา
# 222                                   ตำราหมอดู           มุขตลก
# 223                          เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ
# 224                               ถ้ำคูหาสวรรค์   นิทานประจำถิ่น
# 225                         ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น
#
#                     creator  \
# 0          อ่อนตา ประกาเวสา
# 1                 พ่อใหญ่นู
# 2        หนูเวียง แก้วเวียง
# 3           สมหวัง ปานพายัพ
# 4            บุญศรี เกสเสโร
# 5        พัชราภรณ์ เข็มเพชร
# 6           เพ็ชร ศรีสารคาม
# 7           สุบิน คำยางจ้อง
# 8       ปรางค์ทิพย์ บุญสีลา
# 9             ใจมา สมจันทร์
# 211        เลียบ  พรหมจรรย์
# 212       เอื้อน ทรัพย์แก้ว
# 213                     NaN
# 214                     NaN
# 215                     NaN
# 216           เพิ่ม พวงแก้ว
# 217         รมย์   เผือกแสง
# 218         รมย์   เผือกแสง
# 219          อารี  เส้งวั่น
# 220                     NaN
# 221  หร้อหวาน   วัชรจิรโสภณ
# 222        มาลี   พันธ์วงศ์
# 223                     NaN
# 224                     NaN
# 225                     NaN
#
#                                            description        subject  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน
# 1    <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน
# 3    <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน
# 4    <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน
# 5    <p>มีกลุ่มเพื่อน 3 คนเป็นเพื่อนรักกัน มีแต่คนเ...  นิทานพื้นบ้าน
# 6    <p>เนื้อเรื่องมีอยู่ว่า จากนิทานพื้นบ้าน ครั้ง...  นิทานพื้นบ้าน
# 7    <p>นานมาแล้วมีหลวงพ่อกับเณรน้อยจำวัดอยู่ในหมู่...  นิทานพื้นบ้าน
# 8    <p>วันหนึ่ง ตอนเช้าก่อนหลวงพ่อจะออกไปบินฑบาตร ...  นิทานพื้นบ้าน
# 9    <p>วันหนึ่ง มีหนุ่มอ้วนกับหนุ่มผอม เป็นเพื่อนก...  นิทานพื้นบ้าน
# 211  <p>วันหนึ่งมีไชชายผู้หนึ่งชื่อ &ldquo;ไอ้ดำไม่...  นิทานพื้นบ้าน
# 212  <p>จระเข้กับจิ้งจกเป็นเกลอที่รักชอบกันมากสัญญา...  นิทานพื้นบ้าน
# 213  <p>ในหมู่บ้านแห่งหนึ่ง มีชายคนหนึ่งคิดว่าถ้าตน...  นิทานพื้นบ้าน
# 214  <p>มีครอบครัวหนึ่งมีลูกมากมายและยากจน ซ้ำร้ายล...  นิทานพื้นบ้าน
# 215  <p>ชายคนหนึงชื่อนายปลอก มีนิสัยคดโกง วันหนึ่งไ...  นิทานพื้นบ้าน
# 216  <p>นานมาแล้ว มียายคนหนึ่งได้สอนหลายชายไว้ว่า &...  นิทานพื้นบ้าน
# 217  <p>เณรทองเป็นผีที่อาศัยอยู่ในอุโมงค์ภายในถ้ำใต...  นิทานพื้นบ้าน
# 218  <p>นานมาแล้วตั้งแต่สมัยที่โลกเกิดขึ้นใหม่ๆ นั้...  นิทานพื้นบ้าน
# 219  <p>นานมาแล้วมีหญิงสาวกับชายหนุ่มคู่หนึ่งรักกัน...  นิทานพื้นบ้าน
# 220  <p>ชายชราคนหนึ่งชื่อตาแขนปม ปลูกกระท่อมอยู่กลา...  นิทานพื้นบ้าน
# 221  <p>รายาบือราสะครองเมืองบรือดะ ทรงมีพระราชธิดาพ...  นิทานพื้นบ้าน
# 222  <p>มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน
# 223  <p>มีเต่าตัวหนึ่งเที่ยวหากินอยู่ตามชายป่าใกล้ท...  นิทานพื้นบ้าน
# 224  <p>นานมาแล้ว มีเทวดาอยู่องค์หนึ่งถูกพระอิศวรสา...  นิทานพื้นบ้าน
# 225  <p>ถ้ำเปอร์งง มีลำธารไหลลอดถ้ำออกไปสู่แม่น้ำปั...  นิทานพื้นบ้าน
#
#                spatial  temporal language rights  \
# 0                  ไทย       NaN      ไทย    NaN
# 1                  ไทย       NaN      ไทย    NaN
# 2                  ไทย       NaN      ไทย    NaN
# 3                  ไทย       NaN      ไทย    NaN
# 4                  ไทย       NaN      ไทย    NaN
# 5                  ไทย       NaN      ไทย    NaN
# 6                 ไทย,       NaN      ไทย    NaN
# 7                  ไทย       NaN      ไทย    NaN
# 8                 ไทย,       NaN      ไทย    NaN
# 9                 ไทย,       NaN      ไทย    NaN
# 211  นครศรีธรรมราช ไทย       NaN      ไทย    NaN
# 212                ไทย       NaN      ไทย    NaN
# 213                NaN       NaN      ไทย    NaN
# 214                NaN       NaN      ไทย    NaN
# 215                NaN       NaN      ไทย    NaN
# 216                ไทย       NaN      ไทย    NaN
# 217                ไทย       NaN      ไทย    NaN
# 218                ไทย       NaN      ไทย    NaN
# 219               ไทย,       NaN      ไทย    NaN
# 220                NaN       NaN      ไทย    NaN
# 221                ไทย       NaN      ไทย    NaN
# 222                ไทย       NaN      ไทย    NaN
# 223                NaN       NaN      ไทย    NaN
# 224               ไทย,       NaN      ไทย    NaN
# 225               ไทย,       NaN      ไทย    NaN
#
#                             license  \
# 0    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 1    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 4    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 5    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 6    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 7    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 8    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 9    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 211  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 212  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 213  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 214  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 215  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 216  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 217  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 218  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 219  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 220  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 221  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 222  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 223  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 224  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 225  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri
# 0    https://www.sac.or.th/databases/folktales/folk...
# 1    https://www.sac.or.th/databases/folktales/folk...
# 2    https://www.sac.or.th/databases/folktales/folk...
# 3    https://www.sac.or.th/databases/folktales/folk...
# 4    https://www.sac.or.th/databases/folktales/folk...
# 5    https://www.sac.or.th/databases/folktales/folk...
# 6    https://www.sac.or.th/databases/folktales/folk...
# 7    https://www.sac.or.th/databases/folktales/folk...
# 8    https://www.sac.or.th/databases/folktales/folk...
# 9    https://www.sac.or.th/databases/folktales/folk...
# 211  https://www.sac.or.th/databases/folktales/folk...
# 212  https://www.sac.or.th/databases/folktales/folk...
# 213  https://www.sac.or.th/databases/folktales/folk...
# 214  https://www.sac.or.th/databases/folktales/folk...
# 215  https://www.sac.or.th/databases/folktales/folk...
# 216  https://www.sac.or.th/databases/folktales/folk...
# 217  https://www.sac.or.th/databases/folktales/folk...
# 218  https://www.sac.or.th/databases/folktales/folk...
# 219  https://www.sac.or.th/databases/folktales/folk...
# 220  https://www.sac.or.th/databases/folktales/folk...
# 221  https://www.sac.or.th/databases/folktales/folk...
# 222  https://www.sac.or.th/databases/folktales/folk...
# 223  https://www.sac.or.th/databases/folktales/folk...
# 224  https://www.sac.or.th/databases/folktales/folk...
# 225  https://www.sac.or.th/databases/folktales/folk...

# %%
## อาจารย์พาทำ
# สร้างลิสต์ที่ 10 ตัวแรกเป็น TRUE ตรงกลางเป็น FALSE และ 15 ตัวสุดท้ายเป็น TURE
list_log1 = 10 * [True]
list_log2 = 15 * [True]
list_log3 = (226-25) * [False] # 226 คือ ข้อมูลทั้งหมด 15 คือ ข้อมูลที่เราต้องการ
# สร้าง query
folk_df[list_log1 + list_log3 + list_log2]
# Out:
#                                           title             type  \
# 0                                  ตาบอดคลำช้าง   นิทานประจำถิ่น
# 1                                ขอคำกระฮอกด่อน     ตำนานปรัมปรา
# 2                            ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต
# 3                                     บักหำน้อย           มุขตลก
# 4                                    รื้อบ่อน้ำ           มุขตลก
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ           มุขตลก
# 6                                 ตำนานกุดนางใย   นิทานประจำถิ่น
# 7                                หลวงพ่อน้องงัว           มุขตลก
# 8                             หลวงพ่อกับเณรน้อย           มุขตลก
# 9                               หัวล้านหลื่นครู           มุขตลก
# 211                              งูเหลือมคายพิษ  นิทานอธิบายเหตุ
# 212                             จระเข้กับจิ้งจก  นิทานอธิบายเหตุ
# 213                                     จอมคาถา           มุขตลก
# 214                                 จังไรฉิบหาย           มุขตลก
# 215                                ไชชายนายปลอก       นิทานชีวิต
# 216                              ไชชายเลือกเมีย       นิทานชีวิต
# 217                                      เณรทอง   นิทานประจำถิ่น
# 218                            ดวงอาทิตย์กับไก่  นิทานอธิบายเหตุ
# 219                     ต้นลำพูกับนิทานหิ่งห้อย  นิทานอธิบายเหตุ
# 220                                     ตาแขนปม   นิทานมหัศจรรย์
# 221                                 ตำนานมะโย่ง     ตำนานปรัมปรา
# 222                                   ตำราหมอดู           มุขตลก
# 223                          เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ
# 224                               ถ้ำคูหาสวรรค์   นิทานประจำถิ่น
# 225                         ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น
#
#                     creator  \
# 0          อ่อนตา ประกาเวสา
# 1                 พ่อใหญ่นู
# 2        หนูเวียง แก้วเวียง
# 3           สมหวัง ปานพายัพ
# 4            บุญศรี เกสเสโร
# 5        พัชราภรณ์ เข็มเพชร
# 6           เพ็ชร ศรีสารคาม
# 7           สุบิน คำยางจ้อง
# 8       ปรางค์ทิพย์ บุญสีลา
# 9             ใจมา สมจันทร์
# 211        เลียบ  พรหมจรรย์
# 212       เอื้อน ทรัพย์แก้ว
# 213                     NaN
# 214                     NaN
# 215                     NaN
# 216           เพิ่ม พวงแก้ว
# 217         รมย์   เผือกแสง
# 218         รมย์   เผือกแสง
# 219          อารี  เส้งวั่น
# 220                     NaN
# 221  หร้อหวาน   วัชรจิรโสภณ
# 222        มาลี   พันธ์วงศ์
# 223                     NaN
# 224                     NaN
# 225                     NaN
#
#                                            description        subject  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน
# 1    <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน
# 3    <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน
# 4    <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน
# 5    <p>มีกลุ่มเพื่อน 3 คนเป็นเพื่อนรักกัน มีแต่คนเ...  นิทานพื้นบ้าน
# 6    <p>เนื้อเรื่องมีอยู่ว่า จากนิทานพื้นบ้าน ครั้ง...  นิทานพื้นบ้าน
# 7    <p>นานมาแล้วมีหลวงพ่อกับเณรน้อยจำวัดอยู่ในหมู่...  นิทานพื้นบ้าน
# 8    <p>วันหนึ่ง ตอนเช้าก่อนหลวงพ่อจะออกไปบินฑบาตร ...  นิทานพื้นบ้าน
# 9    <p>วันหนึ่ง มีหนุ่มอ้วนกับหนุ่มผอม เป็นเพื่อนก...  นิทานพื้นบ้าน
# 211  <p>วันหนึ่งมีไชชายผู้หนึ่งชื่อ &ldquo;ไอ้ดำไม่...  นิทานพื้นบ้าน
# 212  <p>จระเข้กับจิ้งจกเป็นเกลอที่รักชอบกันมากสัญญา...  นิทานพื้นบ้าน
# 213  <p>ในหมู่บ้านแห่งหนึ่ง มีชายคนหนึ่งคิดว่าถ้าตน...  นิทานพื้นบ้าน
# 214  <p>มีครอบครัวหนึ่งมีลูกมากมายและยากจน ซ้ำร้ายล...  นิทานพื้นบ้าน
# 215  <p>ชายคนหนึงชื่อนายปลอก มีนิสัยคดโกง วันหนึ่งไ...  นิทานพื้นบ้าน
# 216  <p>นานมาแล้ว มียายคนหนึ่งได้สอนหลายชายไว้ว่า &...  นิทานพื้นบ้าน
# 217  <p>เณรทองเป็นผีที่อาศัยอยู่ในอุโมงค์ภายในถ้ำใต...  นิทานพื้นบ้าน
# 218  <p>นานมาแล้วตั้งแต่สมัยที่โลกเกิดขึ้นใหม่ๆ นั้...  นิทานพื้นบ้าน
# 219  <p>นานมาแล้วมีหญิงสาวกับชายหนุ่มคู่หนึ่งรักกัน...  นิทานพื้นบ้าน
# 220  <p>ชายชราคนหนึ่งชื่อตาแขนปม ปลูกกระท่อมอยู่กลา...  นิทานพื้นบ้าน
# 221  <p>รายาบือราสะครองเมืองบรือดะ ทรงมีพระราชธิดาพ...  นิทานพื้นบ้าน
# 222  <p>มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน
# 223  <p>มีเต่าตัวหนึ่งเที่ยวหากินอยู่ตามชายป่าใกล้ท...  นิทานพื้นบ้าน
# 224  <p>นานมาแล้ว มีเทวดาอยู่องค์หนึ่งถูกพระอิศวรสา...  นิทานพื้นบ้าน
# 225  <p>ถ้ำเปอร์งง มีลำธารไหลลอดถ้ำออกไปสู่แม่น้ำปั...  นิทานพื้นบ้าน
#
#                spatial  temporal language rights  \
# 0                  ไทย       NaN      ไทย    NaN
# 1                  ไทย       NaN      ไทย    NaN
# 2                  ไทย       NaN      ไทย    NaN
# 3                  ไทย       NaN      ไทย    NaN
# 4                  ไทย       NaN      ไทย    NaN
# 5                  ไทย       NaN      ไทย    NaN
# 6                 ไทย,       NaN      ไทย    NaN
# 7                  ไทย       NaN      ไทย    NaN
# 8                 ไทย,       NaN      ไทย    NaN
# 9                 ไทย,       NaN      ไทย    NaN
# 211  นครศรีธรรมราช ไทย       NaN      ไทย    NaN
# 212                ไทย       NaN      ไทย    NaN
# 213                NaN       NaN      ไทย    NaN
# 214                NaN       NaN      ไทย    NaN
# 215                NaN       NaN      ไทย    NaN
# 216                ไทย       NaN      ไทย    NaN
# 217                ไทย       NaN      ไทย    NaN
# 218                ไทย       NaN      ไทย    NaN
# 219               ไทย,       NaN      ไทย    NaN
# 220                NaN       NaN      ไทย    NaN
# 221                ไทย       NaN      ไทย    NaN
# 222                ไทย       NaN      ไทย    NaN
# 223                NaN       NaN      ไทย    NaN
# 224               ไทย,       NaN      ไทย    NaN
# 225               ไทย,       NaN      ไทย    NaN
#
#                             license  \
# 0    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 1    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 4    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 5    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 6    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 7    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 8    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 9    สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 211  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 212  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 213  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 214  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 215  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 216  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 217  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 218  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 219  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 220  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 221  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 222  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 223  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 224  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 225  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri
# 0    https://www.sac.or.th/databases/folktales/folk...
# 1    https://www.sac.or.th/databases/folktales/folk...
# 2    https://www.sac.or.th/databases/folktales/folk...
# 3    https://www.sac.or.th/databases/folktales/folk...
# 4    https://www.sac.or.th/databases/folktales/folk...
# 5    https://www.sac.or.th/databases/folktales/folk...
# 6    https://www.sac.or.th/databases/folktales/folk...
# 7    https://www.sac.or.th/databases/folktales/folk...
# 8    https://www.sac.or.th/databases/folktales/folk...
# 9    https://www.sac.or.th/databases/folktales/folk...
# 211  https://www.sac.or.th/databases/folktales/folk...
# 212  https://www.sac.or.th/databases/folktales/folk...
# 213  https://www.sac.or.th/databases/folktales/folk...
# 214  https://www.sac.or.th/databases/folktales/folk...
# 215  https://www.sac.or.th/databases/folktales/folk...
# 216  https://www.sac.or.th/databases/folktales/folk...
# 217  https://www.sac.or.th/databases/folktales/folk...
# 218  https://www.sac.or.th/databases/folktales/folk...
# 219  https://www.sac.or.th/databases/folktales/folk...
# 220  https://www.sac.or.th/databases/folktales/folk...
# 221  https://www.sac.or.th/databases/folktales/folk...
# 222  https://www.sac.or.th/databases/folktales/folk...
# 223  https://www.sac.or.th/databases/folktales/folk...
# 224  https://www.sac.or.th/databases/folktales/folk...
# 225  https://www.sac.or.th/databases/folktales/folk...

# %% [markdown]
# ### การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
eight_rows_covid = data_covid.iloc[:8,:] # ตารางตัวอย่าง
eight_rows_covid
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6    7     1/26/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 7    8     1/26/2020  ...            หัวหิน  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [8 rows x 10 columns]

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ rows ที่ต้องการ
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']  #เราเอา 2 บรรทัดบนมาบวกกัน
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6    7     1/26/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [6 rows x 10 columns]

# %% [markdown]
# HW (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของผู้ป่วยในจังหวัดขอนแก่น

# %% [markdown]
# 3. หาจำนวนผู้ป่วยที่เป็นคน "**คนต่างชาติเดินทางมาจากต่างประเทศ**"

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
female = this_data[this_data['sex']=='หญิง']
female['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 4        66.0
# 5        33.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 5332, dtype: float64

# %%
sum = 0
N = 0
for a in female['age']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง 36.63955450022614

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น']

sum = 0
N = 0
for a in female_KK['age']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น 41.57142857142857

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# # HW5
# ใช่การ query และ data slicing เพื่อตอบคำถามต่อไไปนี้
#
# 1. นิทานที่ยาวที่สุด และสั้นที่สุด (ไม่นับสัญลักษณ์พิเศษ)
# 2. ชนิดของนิทาน (type) ที่มากที่สุด และน้อยที่สุด
# 3. มี spatail ที่ไม่ใช่ไทยกี่เรื่อง

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
folk_df = pd.read_csv('/content/drive/MyDrive/folktales.csv')
# Out:
# Mounted at /content/drive

# %%
folk_df
# Out:
#                        title             type                 creator  \
# 0               ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1             ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2         ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3                  บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4                 รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                       ...              ...                     ...
# 219  ต้นลำพูกับนิทานหิ่งห้อย  นิทานอธิบายเหตุ          อารี  เส้งวั่น
# 221              ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222                ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 224            ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225      ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0                                   มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1                            ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2       ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3       เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4       วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
# ..                                                 ...            ...     ...
# 219     นานมาแล้วมีหญิงสาวกับชายหนุ่มคู่หนึ่งรักกัน...  นิทานพื้นบ้าน    ไทย,
# 221     รายาบือราสะครองเมืองบรือดะ ทรงมีพระราชธิดาพ...  นิทานพื้นบ้าน     ไทย
# 222     มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน     ไทย
# 224     นานมาแล้ว มีเทวดาอยู่องค์หนึ่งถูกพระอิศวรสา...  นิทานพื้นบ้าน    ไทย,
# 225     ถ้ำเปอร์งง มีลำธารไหลลอดถ้ำออกไปสู่แม่น้ำปั...  นิทานพื้นบ้าน    ไทย,
#
#      temporal language rights                         license  \
# 0         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 1         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 4         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ..        ...      ...    ...                             ...
# 219       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 221       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 222       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 224       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 225       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri  \
# 0    https://www.sac.or.th/databases/folktales/folk...
# 1    https://www.sac.or.th/databases/folktales/folk...
# 2    https://www.sac.or.th/databases/folktales/folk...
# 3    https://www.sac.or.th/databases/folktales/folk...
# 4    https://www.sac.or.th/databases/folktales/folk...
# ..                                                 ...
# 219  https://www.sac.or.th/databases/folktales/folk...
# 221  https://www.sac.or.th/databases/folktales/folk...
# 222  https://www.sac.or.th/databases/folktales/folk...
# 224  https://www.sac.or.th/databases/folktales/folk...
# 225  https://www.sac.or.th/databases/folktales/folk...
#
#                                    cleaned_description  description_length
# 0    descriptiondescriptiondescriptiondescriptionde...                  77
# 1    descriptiondescriptiondescriptiondescriptionde...                  77
# 2    descriptiondescriptiondescriptiondescriptionde...                  77
# 3    descriptiondescriptiondescriptiondescriptionde...                  77
# 4    descriptiondescriptiondescriptiondescriptionde...                  77
# ..                                                 ...                 ...
# 219  descriptiondescriptiondescriptiondescriptionde...                  77
# 221  descriptiondescriptiondescriptiondescriptionde...                  77
# 222  descriptiondescriptiondescriptiondescriptionde...                  77
# 224  descriptiondescriptiondescriptiondescriptionde...                  77
# 225  descriptiondescriptiondescriptiondescriptionde...                  77
#
# [192 rows x 13 columns]

# %% [markdown]
# ข้อที่ 1

# %% [markdown]
# อาจารย์พาทำ

# %%
import re

def remove_htmal_tags(text):
  clean_text = re.sub(r'<.*?>', ' ', text)
  clean_text = re.sub(r'\s+', ' ', clean_text)
  return clean_text

  folk_df['description'] = folk_df['description'].apply(remove_htmal_tags)

# %% [markdown]
# จบ

# %%
import re

# %%
def rm_special_chars(folk_df):
  cleaned_text = re.sub(r'[^\u0E00-\u0E7F\s]', '', folk_df) # เอาสัญลักษณ์พิเศษออก
  return cleaned_text

# %%
folk_df['description'] = folk_df['description'].apply(rm_special_chars) # อัปเดตข้อมูลที่แก้แทนที่ข้อมูลเดิม

# %%
folk_df['description'][3]
# Out:
# '   เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอีสาน กำลังตรวจสุขภาพฟันประจำปีของเด็ก เด็ก ๆ มาต่อคิวเพื่อที่จะตรวจสุขภาพฟัน หมอก็ตรวจเด็กเล็กทีละคน จนมาถึงเด็กผู้ชายคนหนึ่ง เด็กคนนี้มีฟันผุ หมอเลยบอกเด็กคนนี่ว่า    \n\n          โอ        ฟันผุนะจ๊ะหนู อย่างนี้ต้องถอนนะจ๊ะ           \n\n   พอหมอพูดจบก็จัดการฉีดยาชา แล้วก็จัดการถอนฟันที่ผุซี่นั้นออก ด้วยความเจ็บปวดจากการถอนฟัน เด็กคนนั้นจึงร้องไห้ และพอถอนออกเรียบร้อยแล้ว เด็กคนนั้นก็ร้องไห้ไม่หยุดซักที คุณครูผู้ยืนให้กำลังใจเด็กอยู่ เลยถามเด็กน้อยคนนั้นว่า    \n\n          เป็นจั่งใด๋ เจ็บบ่หำ           \n\n   เด็กก็ตอบครูว่า        หำบ่เจ็บครับ เจ็บแต่แข่ว           \n\n   พอทุกคนได้ยินประโยค ที่เด็กคนนั้นพูดจบก็พากันหัวเราะ       ก็เลยเป็นที่มาของนิทานเรื่องที่ว่า        บักหำน้อย                 \n'

# %%
max = folk_df['description'].str.len().max()
min = folk_df['description'].str.len().min()

# %%
print(f'นิทานที่ยาวที่สุดคือ {max} ตัวอักษร')
print(f'นิทานที่สั้นที่สุดคือ {min} ตัวอักษร')
# Out:
# นิทานที่ยาวที่สุดคือ 7863 ตัวอักษร
# นิทานที่สั้นที่สุดคือ 212 ตัวอักษร

# %% [markdown]
# ข้อที่ 2

# %%
max_type = folk_df['type'].value_counts().idxmax()
min_type = folk_df['type'].value_counts().idxmin()
print(f'type ที่มากที่สุดคือ {max_type}')
print(f'type ที่น้อยที่สุดคือ {min_type}')
# Out:
# type ที่มากที่สุดคือ มุขตลก
# type ที่น้อยที่สุดคือ นิทานเข้าแบบ

# %%
# groupby จะรวมคอลัมน์ที่เหมือนกันไว้ด้วยกัน
folk_df.groupby('type').count()
# Out:
#                  title  creator  description  subject  spatial  temporal  \
# type
# ตำนานปรัมปรา         9        8            9        9        7         0
# นิทานชีวิต          41       22           40       41       35         0
# นิทานประจำถิ่น      26       15           25       26       24         0
# นิทานผี              8        2            8        8        8         0
# นิทานมหัศจรรย์      25       12           25       25       23         0
# นิทานวีรบุรุษ        3        0            3        3        3         0
# นิทานศาสนา           8        3            8        8        8         0
# นิทานสัตว์          15        5           14       15       12         0
# นิทานอธิบายเหตุ     39       25           39       39       32         0
# นิทานเข้าแบบ         1        0            1        1        1         0
# มุขตลก              51       33           46       51       47         0
#
#                  language  rights  license  source.uri  cleaned_description  \
# type
# ตำนานปรัมปรา            9       0        9           9                    9
# นิทานชีวิต             41       0       41          41                   41
# นิทานประจำถิ่น         26       0       26          26                   26
# นิทานผี                 8       0        8           8                    8
# นิทานมหัศจรรย์         25       0       25          25                   25
# นิทานวีรบุรุษ           3       0        3           3                    3
# นิทานศาสนา              8       0        8           8                    8
# นิทานสัตว์             15       0       15          15                   15
# นิทานอธิบายเหตุ        39       1       39          39                   39
# นิทานเข้าแบบ            1       0        1           1                    1
# มุขตลก                 51       0       50          51                   51
#
#                  description_length
# type
# ตำนานปรัมปรา                      9
# นิทานชีวิต                       41
# นิทานประจำถิ่น                   26
# นิทานผี                           8
# นิทานมหัศจรรย์                   25
# นิทานวีรบุรุษ                     3
# นิทานศาสนา                        8
# นิทานสัตว์                       15
# นิทานอธิบายเหตุ                  39
# นิทานเข้าแบบ                      1
# มุขตลก                           51

# %% [markdown]
# ข้อที่ 3

# %%
non_th_spatail = folk_df[folk_df['spatial'] != 'ไทย'].shape[0]
print(f'spatail ที่ไม่ใช่ไทยมีทั้งหมด {non_th_spatail} เรื่อง')
# Out:
# spatail ที่ไม่ใช่ไทยมีทั้งหมด 146 เรื่อง

# %% [markdown]
# อาจารย์สอน

# %%
folk_df = folk_df.dropna(subset = {'description'})

# %%
folk_df['spatial'].unique()
# Out:
# array(['ไทย', 'ไทย,', 'ราชบุรี ไทย,', 'พัทลุง ไทย', 'พัทลุง, ไทย',
#        'พัทลุง, ไทย,', 'สงขลา ไทย', 'นครศรีธรรมราช ไทย'], dtype=object)

# %%
folk_df = folk_df.dropna(subset = {'spatial'})
folk_df.shape[0]
# Out:
# 192

# %% [markdown]
# จบ!

# %%
len('มุขตลก')
# Out:
# 6

# %%
folk_df['description'][2]
# Out:
# '<p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำกล้าข้าว ทุกครอบครัวจะออกไปไถนาเตรียมการเพาะปลูกมีครอบครัวของชายหนุ่มคนหนึ่งกำพร้าพ่อก็จะออกไปปฏิบัติภารกิจเช่นเดียวกัน วันหนึ่งเขาไถนาอยู่นานจนสายตะวันขึ้นสูงแล้ว เขารู้สึกเหน็ดเหนื่อยอ่อนเพลียมากกว่าปกติและหิวข้าวมากกว่าทุกวัน ปกติแล้วแม่ผู้ชราจะมาส่งข้าวให้ทุกวัน แต่วันนี้กลับมาช้าผิดปกติเขาจึงหยุดไถนา เข้ามาพักผ่อนอยู่ใต้ต้นไม้ปล่อยเจ้าทุยไปกินหญ้า สายตาเหมือนมองไปทางบ้านรอคอยแม่ที่จะมาส่งข้าวด้วยความรู้สึกกระวนกระวายใจ &nbsp;ยิ่งสายตะวันขึ้นสูงแดดยิ่งร้อนความหิวกระหายยิ่งทวีคูณขึ้น</p>\n\n<p>ทันใดนั้นเขามองเห็นแม่เดินเลียบมาตามคันนา พร้อมกับก่องข้าวน้อยๆ เขารู้สึกไม่พอใจที่แม่เอาก่องข้าวน้อยนั้นมาช้ามาก ด้วยความหิวกระหายจนตาลายอารมณ์พลุ่งพล่าน เขาคิดว่าในก่องข้าวน้อยนั้นคงกินไม่อิ่มเป็นแน่ จึงเอ่ยต่อว่าแม่ของตนว่า &ldquo;อีแก่มึงไปทำอะไรอยู่ถึงมาส่งข้าวให้กูกินช้านัก ก่องข้าวก็เอามาแต่ก่องน้อยๆ กูจะกินอิ่มหรือ&rdquo;</p>\n\n<p>ผู้เป็นแม่เอ่ยปากตอบลูกว่า &nbsp; &nbsp; &nbsp;&ldquo;ถึงก่องข้าวจะน้อยแต่ก็น้อยต้อนแต้นแน่นในดอกลูกเอ๋ย ลองกินเบิ่งก่อน&rdquo;</p>\n\n<p>ความหิว ความเหน็ดเหนื่อย ความโมโหหูอื้อตาลาย ไม่ยอมฟังเสียงใดๆเกิดบันดาลโทสะอย่างแรง จึงคว้าได้ไม้เข้าตีแม่ที่แก่ชราล้มลงแล้วเดินไปกินข้าวจนอิ่มแล้วแต่ข้าวยังไม่หมดก่อง จึงรู้สึกผิดชอบชั่วดีรีบไปดูอาการของแม่ และเข้ามาสวมกอดแม่ชายหนุ่มร้องไห้โฮ สำนึกผิดที่ฆ่าแม่ของตนด้วยอารมณ์เพียงชั่ววูบ เมื่อชายหนุ่มปลงศพแม่แล้วขอร้องชักชวนญาติมิตรชาวบ้าน ช่วยกันปั้นอิฐก่อเป็นธาตุเจดีย์บรรจุอัฐิแม่ไว้จึงให้ชื่อว่า &ldquo;ธาตุก่องข้าวน้อยฆ่าแม่&rdquo; จนตราบทุกวันนี้</p>\n'

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
this_data.shape #(12423, 3)
# Out:
# (12653, 3)

# %%
print(data_covid.shape)
print(data_covid.dropna().shape)
# Out:
# (12653, 10)
# (6655, 10)

# %%
this_data.dropna().shape
# Out:
# (8478, 3)

# %%
this_data.dropna()
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8478 rows x 3 columns]

# %%
this_data.dropna()
print(this_data.shape)
# Out:
# (12653, 3)

# %%
this_data.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
this_data.dropna(inplace=True)
print(this_data.shape)
# Out:
# (8478, 3)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
this_data = data_covid[['sex','age','province_of_onset']]
this_data.shape
# Out:
# (12653, 3)

# %%
this_data.dropna().shape
# Out:
# (8478, 3)

# %%
this_data.dropna(subset=['age']).shape
# Out:
# (8881, 3)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f'จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=["province_of_onset"]).shape[0]}')
# Out:
# จำนวน record ก่อน drop missing ใน province 12653
# จำนวน record หลัง drop missing ใน province 10662

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้', 'age':-1, 'province_of_onset':'ไม่รู้'})
this_data_updated.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data_updated[this_data_updated['sex']=='ไม่รู้']
# Out:
#           sex  age province_of_onset
# 4391   ไม่รู้ -1.0         สมุทรสาคร
# 4392   ไม่รู้ -1.0         สมุทรสาคร
# 4393   ไม่รู้ -1.0         สมุทรสาคร
# 4394   ไม่รู้ -1.0         สมุทรสาคร
# 4395   ไม่รู้ -1.0         สมุทรสาคร
# ...       ...  ...               ...
# 12635  ไม่รู้ -1.0         สมุทรสาคร
# 12636  ไม่รู้ -1.0         สมุทรสาคร
# 12637  ไม่รู้ -1.0         สมุทรสาคร
# 12638  ไม่รู้ -1.0         สมุทรสาคร
# 12639  ไม่รู้ -1.0         สมุทรสาคร
#
# [2502 rows x 3 columns]

# %%
this_data_updated['province_of_onset']=='ไม่รู้'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# Name: province_of_onset, Length: 12653, dtype: bool

# %%
data_covid[this_data_updated['province_of_onset']=='ไม่รู้']
# Out:
#          No.  ...                                         risk
# 414      415  ...                                      สนามมวย
# 529      530  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 555      556  ...                                      สนามมวย
# 576      577  ...                                      สนามมวย
# 588      589  ...                         อยู่ระหว่างการสอบสวน
# ...      ...  ...                                          ...
# 12405  12406  ...                            Cluster สมุทรสาคร
# 12406  12407  ...                            Cluster สมุทรสาคร
# 12407  12408  ...                            Cluster สมุทรสาคร
# 12408  12409  ...                            Cluster สมุทรสาคร
# 12409  12410  ...                            Cluster สมุทรสาคร
#
# [1991 rows x 10 columns]

# %%
this_data_updated_2 = this_data.fillna(value={'province_of_onset':'ไม่รู้'})

# %%
this_data_updated_2[this_data_updated['sex']=='ไม่รู้']
# Out:
#        sex  age province_of_onset
# 4391   NaN  NaN         สมุทรสาคร
# 4392   NaN  NaN         สมุทรสาคร
# 4393   NaN  NaN         สมุทรสาคร
# 4394   NaN  NaN         สมุทรสาคร
# 4395   NaN  NaN         สมุทรสาคร
# ...    ...  ...               ...
# 12635  NaN  NaN         สมุทรสาคร
# 12636  NaN  NaN         สมุทรสาคร
# 12637  NaN  NaN         สมุทรสาคร
# 12638  NaN  NaN         สมุทรสาคร
# 12639  NaN  NaN         สมุทรสาคร
#
# [2502 rows x 3 columns]

# %% [markdown]
# ### ลบเฉพาะค่าว่างใน column ที่เราต้องใช้

# %%
this_data = folk_df.copy()

# %%
this_data = this_data.dropna(inplace = True)

# %%
this_data = folk_df.dropna(subset = ['title', 'description', 'type']) # สมมติ เราต้องใช้ ค่าในคอลัมน์
this_data
# Out:
#                        title             type                 creator  \
# 0               ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1             ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2         ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3                  บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4                 รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                       ...              ...                     ...
# 219  ต้นลำพูกับนิทานหิ่งห้อย  นิทานอธิบายเหตุ          อารี  เส้งวั่น
# 221              ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222                ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 224            ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225      ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0                                   มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1                            ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2       ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3       เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4       วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
# ..                                                 ...            ...     ...
# 219     นานมาแล้วมีหญิงสาวกับชายหนุ่มคู่หนึ่งรักกัน...  นิทานพื้นบ้าน    ไทย,
# 221     รายาบือราสะครองเมืองบรือดะ ทรงมีพระราชธิดาพ...  นิทานพื้นบ้าน     ไทย
# 222     มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน     ไทย
# 224     นานมาแล้ว มีเทวดาอยู่องค์หนึ่งถูกพระอิศวรสา...  นิทานพื้นบ้าน    ไทย,
# 225     ถ้ำเปอร์งง มีลำธารไหลลอดถ้ำออกไปสู่แม่น้ำปั...  นิทานพื้นบ้าน    ไทย,
#
#      temporal language rights                         license  \
# 0         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 1         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 4         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ..        ...      ...    ...                             ...
# 219       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 221       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 222       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 224       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 225       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri  \
# 0    https://www.sac.or.th/databases/folktales/folk...
# 1    https://www.sac.or.th/databases/folktales/folk...
# 2    https://www.sac.or.th/databases/folktales/folk...
# 3    https://www.sac.or.th/databases/folktales/folk...
# 4    https://www.sac.or.th/databases/folktales/folk...
# ..                                                 ...
# 219  https://www.sac.or.th/databases/folktales/folk...
# 221  https://www.sac.or.th/databases/folktales/folk...
# 222  https://www.sac.or.th/databases/folktales/folk...
# 224  https://www.sac.or.th/databases/folktales/folk...
# 225  https://www.sac.or.th/databases/folktales/folk...
#
#                                    cleaned_description  description_length
# 0    descriptiondescriptiondescriptiondescriptionde...                  77
# 1    descriptiondescriptiondescriptiondescriptionde...                  77
# 2    descriptiondescriptiondescriptiondescriptionde...                  77
# 3    descriptiondescriptiondescriptiondescriptionde...                  77
# 4    descriptiondescriptiondescriptiondescriptionde...                  77
# ..                                                 ...                 ...
# 219  descriptiondescriptiondescriptiondescriptionde...                  77
# 221  descriptiondescriptiondescriptiondescriptionde...                  77
# 222  descriptiondescriptiondescriptiondescriptionde...                  77
# 224  descriptiondescriptiondescriptiondescriptionde...                  77
# 225  descriptiondescriptiondescriptiondescriptionde...                  77
#
# [192 rows x 13 columns]

# %% [markdown]
# ### ตรวจสอบค่าว่าง

# %%
folk_df['type'].mode() # หาฐานนิยม
# Out:
# 0    มุขตลก
# Name: type, dtype: object

# %%
# ตรวจสอบหาว่าง ช่องในว่างเป็น True ถ้าไม่ว่างเป็น False
folk_df['type'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 219    False
# 221    False
# 222    False
# 224    False
# 225    False
# Name: type, Length: 192, dtype: bool

# %%
folk_df['type'].isnull().any() # เอาทุกค่าใน list มา OR กัน (เราใช้อันนี้เพราะ ถ้ามี Ture แค่ ) ค่ามันจะเป็น Ture
# Out:
# False

# %%
folk_df['type'].isnull().all() # เอาทุกค่าใน list มา AND กัน (เราใช้อันนี้เพราะ ถ้ามี False แค่ ) ค่ามันจะเป็น False
# Out:
# False

# %% [markdown]
# ## Quize7 นิทานเรื่องไหนที่ค่า spatial เป็นค่าว่าง (ไม่ใช้ gemini)

# %%
folk_df = pd.read_csv('/content/drive/MyDrive/folktales.csv')

# %%
folk_df['spatial'].isnull().any()
# Out:
# True

# %%
folk_df[folk_df['spatial'].isnull()].shape[0] # จำนวนเรื่องที่ค่า spatial เป็นค่าว่าง
# Out:
# 26

# %%
folk_df[folk_df['spatial'].isnull()]
# Out:
#                      title             type  \
# 34               พญาคันคาก     ตำนานปรัมปรา
# 75               พญาคันคาก     ตำนานปรัมปรา
# 76                 ผีตาแฮก  นิทานอธิบายเหตุ
# 88         ทุ่งกุลาฮ่องไห้   นิทานประจำถิ่น
# 96               นางหมาขาว   นิทานมหัศจรรย์
# 112             ธุระไม่ใช่       นิทานชีวิต
# 113       ทำไมเสือจึงมีลาย  นิทานอธิบายเหตุ
# 121          สามสหายสามโรค           มุขตลก
# 148             ลิงกับเต่า       นิทานสัตว์
# 149                  ปูทอง       นิทานสัตว์
# 150         ศุภมิตร-เกศินี       นิทานชีวิต
# 173         คงรอดกับยอดทอง       นิทานชีวิต
# 183               นกบินหลา  นิทานอธิบายเหตุ
# 184  คนเลี้ยงเป็ดเจ้าปัญญา  นิทานอธิบายเหตุ
# 185         งูเหลือมวิดปลา  นิทานอธิบายเหตุ
# 192          กรรมเก่าของกา  นิทานอธิบายเหตุ
# 193              กระดูกไก่       นิทานชีวิต
# 197       การละอายความชั่ว       นิทานชีวิต
# 202                 คนทีดำ   นิทานประจำถิ่น
# 206               คนพาซื่อ       นิทานสัตว์
# 209          ค่อยโถเอาใหม่           มุขตลก
# 213                จอมคาถา           มุขตลก
# 214            จังไรฉิบหาย           มุขตลก
# 215           ไชชายนายปลอก       นิทานชีวิต
# 220                ตาแขนปม   นิทานมหัศจรรย์
# 223     เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ
#
#                                 creator  \
# 34                    ภัสดาภร อินทะบุตร
# 75                                  NaN
# 76   อ้วน ธีจันทร์มาตย์,บุญเลิศ ไชยพงษ์
# 88                                  NaN
# 96                                  NaN
# 112                                 NaN
# 113                                 NaN
# 121                                 NaN
# 148                                 NaN
# 149                                 NaN
# 150                                 NaN
# 173                                 NaN
# 183                                 NaN
# 184                                 NaN
# 185                                 NaN
# 192                                 NaN
# 193                                 NaN
# 197                                 NaN
# 202                    แรม   เทพนุรักษ์
# 206                                 NaN
# 209                                 NaN
# 213                                 NaN
# 214                                 NaN
# 215                                 NaN
# 220                                 NaN
# 223                                 NaN
#
#                                            description        subject spatial  \
# 34   <p>พระนางสีดา มเหสีของพระยาเอกราชผู้ครองเมือง ...  นิทานพื้นบ้าน     NaN
# 75   <p>พญาคันคาก เป็นราชาครองเมืองชมพู บรรดาบ้านเม...  นิทานพื้นบ้าน     NaN
# 76   <p>กาลครั้งหนึ่ง มีชาย 2 คนพ่อลูก พอลูกชายโตก็...  นิทานพื้นบ้าน     NaN
# 88   <p>ในสมัยก่อนมีพ่อค้าอยู่เมืองลาว เรียกว่า พวก...  นิทานพื้นบ้าน     NaN
# 96   <p>มีสองผัวเมียอาศัยอยู่ในหมู่บ้านจันทคาม ซึ่ง...  นิทานพื้นบ้าน     NaN
# 112  <p>มีชาวนาสองคนผัวเมียก่อร่างสร้างตัวจนเป็นเศร...  นิทานพื้นบ้าน     NaN
# 113  <p>น้ำจะท่วมฟ้า ปลาจะกินดาวกินสมัยโบราณ คนกับส...  นิทานพื้นบ้าน     NaN
# 121  <p>&nbsp;มีเพื่อนสหายสามคนมีอาการเป็นโรคคนละอย...  นิทานพื้นบ้าน     NaN
# 148  <p>นานมาแล้วที่หมู่บ้านแห่งหนึ่ง มีเด็กคนหนึ่ง...  นิทานพื้นบ้าน     NaN
# 149  <p>นานมาแล้ว มีชายหนุ่มคนหนึ่งอาศัยอยู่ในหมู่บ...  นิทานพื้นบ้าน     NaN
# 150  <p>เมืองจำปาก มีพระเจ้าศุภมิตรและพระนางเกศินีค...  นิทานพื้นบ้าน     NaN
# 173  <p>คงรอดกับยอดทองเป็นเกลอกัน แต่อยู่คนละหมู่บ้...  นิทานพื้นบ้าน     NaN
# 183  <p>มีชายอยู่คนหนึ่งไปนั่งถ่ายอุจจาระบนขอนไม้ใน...  นิทานพื้นบ้าน     NaN
# 184  <p>มีลุงอยู่คนหนึ่งมีอาชีพเลี้ยงเป็ดไข่ แกเลี้...  นิทานพื้นบ้าน     NaN
# 185  <p>สมัยก่อนงูเหลือมเป็นสัตว์ที่มีพิษมากและร้าย...  นิทานพื้นบ้าน     NaN
# 192  <p>นานมาแล้วนกฮูกท้องผูกถ่ายไม่ออก จึงไปหากาให...  นิทานพื้นบ้าน     NaN
# 193  <p>มีหนุ่มยากจนคนหนึ่งชื่อ สุธน โชคดีได้แต่งงา...  นิทานพื้นบ้าน     NaN
# 197  <p>อาจารย์คนหนึ่งสอนศิษย์สำเร็จวิชาแล้วก็เรียก...  นิทานพื้นบ้าน     NaN
# 202  <p>เรื่องคนทีดำ : กาลครั้งหนึ่งมีชายหนุ่ม 3 คน...  นิทานพื้นบ้าน     NaN
# 206  <p>ชายคนหนึ่งเป็นคนที่ซื่อตรงมาก วันหนึ่งแกไปเ...  นิทานพื้นบ้าน     NaN
# 209  <p>ยังมีชายหนุ่มผู้หนึ่งได้รับขวานเล่มหนึ่งเป็...  นิทานพื้นบ้าน     NaN
# 213  <p>ในหมู่บ้านแห่งหนึ่ง มีชายคนหนึ่งคิดว่าถ้าตน...  นิทานพื้นบ้าน     NaN
# 214  <p>มีครอบครัวหนึ่งมีลูกมากมายและยากจน ซ้ำร้ายล...  นิทานพื้นบ้าน     NaN
# 215  <p>ชายคนหนึงชื่อนายปลอก มีนิสัยคดโกง วันหนึ่งไ...  นิทานพื้นบ้าน     NaN
# 220  <p>ชายชราคนหนึ่งชื่อตาแขนปม ปลูกกระท่อมอยู่กลา...  นิทานพื้นบ้าน     NaN
# 223  <p>มีเต่าตัวหนึ่งเที่ยวหากินอยู่ตามชายป่าใกล้ท...  นิทานพื้นบ้าน     NaN
#
#      temporal language rights                         license  \
# 34        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 75        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 76        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 88        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 96        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 112       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 113       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 121       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 148       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 149       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 150       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 173       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 183       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 184       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 185       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 192       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 193       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 197       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 202       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 206       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 209       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 213       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 214       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 215       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 220       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 223       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri
# 34   https://www.sac.or.th/databases/folktales/folk...
# 75   https://www.sac.or.th/databases/folktales/folk...
# 76   https://www.sac.or.th/databases/folktales/folk...
# 88   https://www.sac.or.th/databases/folktales/folk...
# 96   https://www.sac.or.th/databases/folktales/folk...
# 112  https://www.sac.or.th/databases/folktales/folk...
# 113  https://www.sac.or.th/databases/folktales/folk...
# 121  https://www.sac.or.th/databases/folktales/folk...
# 148  https://www.sac.or.th/databases/folktales/folk...
# 149  https://www.sac.or.th/databases/folktales/folk...
# 150  https://www.sac.or.th/databases/folktales/folk...
# 173  https://www.sac.or.th/databases/folktales/folk...
# 183  https://www.sac.or.th/databases/folktales/folk...
# 184  https://www.sac.or.th/databases/folktales/folk...
# 185  https://www.sac.or.th/databases/folktales/folk...
# 192  https://www.sac.or.th/databases/folktales/folk...
# 193  https://www.sac.or.th/databases/folktales/folk...
# 197  https://www.sac.or.th/databases/folktales/folk...
# 202  https://www.sac.or.th/databases/folktales/folk...
# 206  https://www.sac.or.th/databases/folktales/folk...
# 209  https://www.sac.or.th/databases/folktales/folk...
# 213  https://www.sac.or.th/databases/folktales/folk...
# 214  https://www.sac.or.th/databases/folktales/folk...
# 215  https://www.sac.or.th/databases/folktales/folk...
# 220  https://www.sac.or.th/databases/folktales/folk...
# 223  https://www.sac.or.th/databases/folktales/folk...

# %%
folk_df[folk_df['title'].duplicated()].shape[0] # จำนวนเรื่องที่ซ้ำกัน
# Out:
# 6

# %%
folk_df[folk_df['title'].duplicated(keep = False)]
# Out:
#                   title            type             creator  \
# 2    ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 32   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น  หนูเวียง แก้วเวียง
# 34            พญาคันคาก    ตำนานปรัมปรา   ภัสดาภร อินทะบุตร
# 38         กำพร้าผีน้อย      นิทานชีวิต                 NaN
# 43   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น                 NaN
# 49             ผีกองกอย         นิทานผี                 NaN
# 75            พญาคันคาก    ตำนานปรัมปรา                 NaN
# 95         กำพร้าผีน้อย         นิทานผี                 NaN
# 100            ผีกองกอย         นิทานผี                 NaN
# 142            ผีกองกอย         นิทานผี                 NaN
#
#                                            description        subject spatial  \
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 32   <p>กาลครั้งหนึ่งนานมาแล้ว ในฤดูฝนนั้นจะมาการเต...  นิทานพื้นบ้าน     ไทย
# 34   <p>พระนางสีดา มเหสีของพระยาเอกราชผู้ครองเมือง ...  นิทานพื้นบ้าน     NaN
# 38                                                 NaN  นิทานพื้นบ้าน     ไทย
# 43   <p>ชาวนาครอบครัวหนึ่งในจังหวัดยโสธร มีแม่กับลู...  นิทานพื้นบ้าน     ไทย
# 49   <p>ในหมู่บ้านแห่งหนึ่งมีท้าวขึ้คร้านเดินขออาหา...  นิทานพื้นบ้าน    ไทย,
# 75   <p>พญาคันคาก เป็นราชาครองเมืองชมพู บรรดาบ้านเม...  นิทานพื้นบ้าน     NaN
# 95   <p>ขณะที่รอการเก็บเกี่ยวข้าว ท้าวกำพร้าได้ออกข...  นิทานพื้นบ้าน    ไทย,
# 100  <p>ท้าวขี้คร้านไม่ทำการทำงานได้แต่ขออาหารชาวบ้...  นิทานพื้นบ้าน    ไทย,
# 142  <p>&nbsp; &nbsp; &nbsp; กาลครั้งหนึ่งนานมาแล้ว...  นิทานพื้นบ้าน     ไทย
#
#      temporal language rights                         license  \
# 2         NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 32        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 34        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 38        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 43        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 49        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 75        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 95        NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 100       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 142       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri
# 2    https://www.sac.or.th/databases/folktales/folk...
# 32   https://www.sac.or.th/databases/folktales/folk...
# 34   https://www.sac.or.th/databases/folktales/folk...
# 38   https://www.sac.or.th/databases/folktales/folk...
# 43   https://www.sac.or.th/databases/folktales/folk...
# 49   https://www.sac.or.th/databases/folktales/folk...
# 75   https://www.sac.or.th/databases/folktales/folk...
# 95   https://www.sac.or.th/databases/folktales/folk...
# 100  https://www.sac.or.th/databases/folktales/folk...
# 142  https://www.sac.or.th/databases/folktales/folk...

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
this_data = folk_df.copy()

# %%
this_data = folk_df[['title', 'type', 'creator']]
this_data
# Out:
#                    title             type                 creator
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
# [226 rows x 3 columns]

# %%
for each_row in this_data.iterrows():
    # print(each_row)
    print(each_row,end='\n*********************************\n')
# Out:
# (0, title          ตาบอดคลำช้าง
# type         นิทานประจำถิ่น
# creator    อ่อนตา ประกาเวสา
# Name: 0, dtype: object)
# *********************************
# (1, title      ขอคำกระฮอกด่อน
# type         ตำนานปรัมปรา
# creator         พ่อใหญ่นู
# Name: 1, dtype: object)
# *********************************
# (2, title      ก่องข้าวน้อยฆ่าแม่
# type               นิทานชีวิต
# creator    หนูเวียง แก้วเวียง
# Name: 2, dtype: object)
# *********************************
# (3, title            บักหำน้อย
# type                มุขตลก
# creator    สมหวัง ปานพายัพ
# Name: 3, dtype: object)
# *********************************
# (4, title          รื้อบ่อน้ำ
# type               มุขตลก
# creator    บุญศรี เกสเสโร
# Name: 4, dtype: object)
# *********************************
# (5, title      กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ
# type                                           มุขตลก
# creator                            พัชราภรณ์ เข็มเพชร
# Name: 5, dtype: object)
# *********************************
# (6, title        ตำนานกุดนางใย
# type        นิทานประจำถิ่น
# creator    เพ็ชร ศรีสารคาม
# Name: 6, dtype: object)
# *********************************
# (7, title       หลวงพ่อน้องงัว
# type                มุขตลก
# creator    สุบิน คำยางจ้อง
# Name: 7, dtype: object)
# *********************************
# (8, title        หลวงพ่อกับเณรน้อย
# type                    มุขตลก
# creator    ปรางค์ทิพย์ บุญสีลา
# Name: 8, dtype: object)
# *********************************
# (9, title      หัวล้านหลื่นครู
# type                มุขตลก
# creator      ใจมา สมจันทร์
# Name: 9, dtype: object)
# *********************************
# (10, title         ซิ่นสองต่อน
# type       นิทานประจำถิ่น
# creator               NaN
# Name: 10, dtype: object)
# *********************************
# (11, title      เซียงเมี่ยง ตอนหลอกเจ้าเมืองลงน้ำ
# type                                  มุขตลก
# creator                     เพ็ญนภา พันพินิจ
# Name: 11, dtype: object)
# *********************************
# (12, title         แม่ใหญ่แฮก
# type        ตำนานปรัมปรา
# creator    ชลิตา โพธิสาร
# Name: 12, dtype: object)
# *********************************
# (13, title      ทำไมมนุษย์จึงรู้จักการกินเมล็ดข้าว
# type                          นิทานอธิบายเหตุ
# creator                    สร้อยอุมา หอมกลิ่น
# Name: 13, dtype: object)
# *********************************
# (14, title       ปัญญาของพ่อ
# type         นิทานชีวิต
# creator    ไพบูลย์ ระหา
# Name: 14, dtype: object)
# *********************************
# (15, title      ศรีธนนชัย ตอนเลี้ยงน้อง
# type                    นิทานชีวิต
# creator           อุทัย ต้องโพนทอง
# Name: 15, dtype: object)
# *********************************
# (16, title      สร้อยขี้ตะกั่ว
# type           นิทานชีวิต
# creator       นฤมล รองทอง
# Name: 16, dtype: object)
# *********************************
# (17, title             ขายปัญญา
# type       นิทานอธิบายเหตุ
# creator      บรรลุ หารเสนา
# Name: 17, dtype: object)
# *********************************
# (18, title           จับราว
# type            มุขตลก
# creator    ชารี คำสีมา
# Name: 18, dtype: object)
# *********************************
# (19, title       บักแหมบกับอีทา
# type                มุขตลก
# creator    สุนีย์ คุณโพธิ์
# Name: 19, dtype: object)
# *********************************
# (20, title      แม่เฒ่ากับลูกเขย
# type                 มุขตลก
# creator     สุนีย์ คุณโพธิ์
# Name: 20, dtype: object)
# *********************************
# (21, title                 จำปาสี่ต้น
# type              นิทานมหัศจรรย์
# creator    ยายบุญเลียง พ่อครวงค์
# Name: 21, dtype: object)
# *********************************
# (22, title      หลวงพ่อกลัวผีหลอก
# type                  มุขตลก
# creator          เสาร์ จันกอ
# Name: 22, dtype: object)
# *********************************
# (23, title      หลวงพ่อเข้าลอดช่อง
# type                   มุขตลก
# creator           เสาร์ จันกอ
# Name: 23, dtype: object)
# *********************************
# (24, title             ลูกหลงพ่อ
# type                 มุขตลก
# creator    จันทร์ โพธิ์ไทสง
# Name: 24, dtype: object)
# *********************************
# (25, title         เจ็ดหวดเจ็ดไห
# type                 มุขตลก
# creator    จันทร์ โพธิ์ไทสง
# Name: 25, dtype: object)
# *********************************
# (26, title          ท้าวหมาหยุ๋ย
# type         นิทานมหัศจรรย์
# creator    พระอินดา กวีวงศ์
# Name: 26, dtype: object)
# *********************************
# (27, title             บอดตาใส
# type               มุขตลก
# creator    สดศรี  ศิริเวช
# Name: 27, dtype: object)
# *********************************
# (28, title           บั้งปัญญา
# type           นิทานสัตว์
# creator    แถว เนืองวัฒนะ
# Name: 28, dtype: object)
# *********************************
# (29, title      คนไม่มีคุณ
# type       นิทานสัตว์
# creator           NaN
# Name: 29, dtype: object)
# *********************************
# (30, title      บักขาติด กับบักตาบอด
# type                     มุขตลก
# creator     เสมียน พิบูลย์สังข์
# Name: 30, dtype: object)
# *********************************
# (31, title               ไม้เท้าผ้าดำ
# type             นิทานอธิบายเหตุ
# creator    หอย ยะพลหา,จูม ไกยะษา
# Name: 31, dtype: object)
# *********************************
# (32, title      ก่องข้าวน้อยฆ่าแม่
# type           นิทานประจำถิ่น
# creator    หนูเวียง แก้วเวียง
# Name: 32, dtype: object)
# *********************************
# (33, title              หูดสามเปา
# type                  มุขตลก
# creator    ภัสดาภร อินทะบุตร
# Name: 33, dtype: object)
# *********************************
# (34, title              พญาคันคาก
# type            ตำนานปรัมปรา
# creator    ภัสดาภร อินทะบุตร
# Name: 34, dtype: object)
# *********************************
# (35, title            ผาแดงนางไอ่
# type            ตำนานปรัมปรา
# creator    ภัสดาภร อินทะบุตร
# Name: 35, dtype: object)
# *********************************
# (36, title      ศรีทนนท์ชัย (ตอนเลี้ยงน้อง)
# type                        นิทานชีวิต
# creator                            NaN
# Name: 36, dtype: object)
# *********************************
# (37, title      คาดสิทุกข์บ่ฮอนมี
# type                  มุขตลก
# creator                  NaN
# Name: 37, dtype: object)
# *********************************
# (38, title      กำพร้าผีน้อย
# type         นิทานชีวิต
# creator             NaN
# Name: 38, dtype: object)
# *********************************
# (39, title      เซี่ยงเมี่ยงกับช้างและเสือ
# type                       นิทานสัตว์
# creator                           NaN
# Name: 39, dtype: object)
# *********************************
# (40, title      ปะติโมง
# type        มุขตลก
# creator        NaN
# Name: 40, dtype: object)
# *********************************
# (41, title      หลวงพ่อกับน้องงัว
# type                  มุขตลก
# creator                  NaN
# Name: 41, dtype: object)
# *********************************
# (42, title      เณรน้อยขี้ไก่โป
# type                มุขตลก
# creator                NaN
# Name: 42, dtype: object)
# *********************************
# (43, title      ก่องข้าวน้อยฆ่าแม่
# type           นิทานประจำถิ่น
# creator                   NaN
# Name: 43, dtype: object)
# *********************************
# (44, title      ท้าวกำพร้าหมากเขือ
# type           นิทานมหัศจรรย์
# creator                   NaN
# Name: 44, dtype: object)
# *********************************
# (45, title      ผีหวงผัว
# type        นิทานผี
# creator         NaN
# Name: 45, dtype: object)
# *********************************
# (46, title      พ่อตากับลูกเขย ตอน ลูกเขยขายขี้
# type                                มุขตลก
# creator                                NaN
# Name: 46, dtype: object)
# *********************************
# (47, title      ภรรยาปากพาทุกข์พายาก
# type            นิทานอธิบายเหตุ
# creator                     NaN
# Name: 47, dtype: object)
# *********************************
# (48, title      พ่อตากับลูกเขยใหม่
# type                   มุขตลก
# creator                   NaN
# Name: 48, dtype: object)
# *********************************
# (49, title      ผีกองกอย
# type        นิทานผี
# creator         NaN
# Name: 49, dtype: object)
# *********************************
# (50, title      ทำไมต้องมัดตราสังศพด้วยด้ายสายสิญจน์
# type                            นิทานอธิบายเหตุ
# creator                              พ่อใหญ่เคน
# Name: 50, dtype: object)
# *********************************
# (51, title      ผีขาเดียว
# type         นิทานผี
# creator          NaN
# Name: 51, dtype: object)
# *********************************
# (52, title      ทำไมกระต่ายถึงมีหางสั้น
# type               นิทานอธิบายเหตุ
# creator                        NaN
# Name: 52, dtype: object)
# *********************************
# (53, title      หลวงพ่ออยากกินจิ้งหรีด
# type                       มุขตลก
# creator                       NaN
# Name: 53, dtype: object)
# *********************************
# (54, title      นกกาเหว่าสองพี่น้อง
# type                นิทานสัตว์
# creator                    NaN
# Name: 54, dtype: object)
# *********************************
# (55, title      มะม่วงของพระราชา
# type                 มุขตลก
# creator                 NaN
# Name: 55, dtype: object)
# *********************************
# (56, title      สี่สหาย
# type        มุขตลก
# creator        NaN
# Name: 56, dtype: object)
# *********************************
# (57, title      หมาจิ้งจอกอยากกินกุ้ง
# type                  นิทานสัตว์
# creator                      NaN
# Name: 57, dtype: object)
# *********************************
# (58, title      พญาช้างผู้อารี
# type       นิทานมหัศจรรย์
# creator               NaN
# Name: 58, dtype: object)
# *********************************
# (59, title      งูเขียวน้อยจอมขี้เกียจ
# type                   นิทานสัตว์
# creator                       NaN
# Name: 59, dtype: object)
# *********************************
# (60, title      สะใภ้ใหญ่กับสะใภ้รอง
# type                 นิทานชีวิต
# creator                     NaN
# Name: 60, dtype: object)
# *********************************
# (61, title      อยากรวยแต่ถูกหวยกิน
# type           นิทานอธิบายเหตุ
# creator                    NaN
# Name: 61, dtype: object)
# *********************************
# (62, title          กำเนิดหอยขม
# type       นิทานอธิบายเหตุ
# creator                NaN
# Name: 62, dtype: object)
# *********************************
# (63, title         นกฮูกกับอีกา
# type       นิทานอธิบายเหตุ
# creator                NaN
# Name: 63, dtype: object)
# *********************************
# (64, title      ใบตองกุง
# type         มุขตลก
# creator         NaN
# Name: 64, dtype: object)
# *********************************
# (65, title        แมวบักคำ
# type       นิทานสัตว์
# creator           NaN
# Name: 65, dtype: object)
# *********************************
# (66, title          กาขาว กาดำ
# type       นิทานมหัศจรรย์
# creator               NaN
# Name: 66, dtype: object)
# *********************************
# (67, title      หลวงพ่อไม้ไผ่ หลวงพ่อมะเขือ
# type                            มุขตลก
# creator                            NaN
# Name: 67, dtype: object)
# *********************************
# (68, title       นางสิบสอง
# type       นิทานชีวิต
# creator           NaN
# Name: 68, dtype: object)
# *********************************
# (69, title      คนจีนกับหลวงพ่อเจ้าอาวาส
# type                 นิทานประจำถิ่น
# creator            อ่อนตา ประกาเวสา
# Name: 69, dtype: object)
# *********************************
# (70, title       ลูกเขยใหม่
# type        นิทานชีวิต
# creator    คำเบา แทนนา
# Name: 70, dtype: object)
# *********************************
# (71, title      เศรษฐียกสมบัติให้ลูก
# type                 นิทานชีวิต
# creator               พ่อใหญ่นู
# Name: 71, dtype: object)
# *********************************
# (72, title       ผีสองหัว
# type         นิทานผี
# creator    พ่อใหญ่นู
# Name: 72, dtype: object)
# *********************************
# (73, title      ข้าวเม่าอ่อน
# type             มุขตลก
# creator     คำเบา แทนนา
# Name: 73, dtype: object)
# *********************************
# (74, title      คางคก ลิง และเสือ
# type              นิทานสัตว์
# creator     อ่อนตา ประกาเวสา
# Name: 74, dtype: object)
# *********************************
# (75, title         พญาคันคาก
# type       ตำนานปรัมปรา
# creator             NaN
# Name: 75, dtype: object)
# *********************************
# (76, title                                 ผีตาแฮก
# type                          นิทานอธิบายเหตุ
# creator    อ้วน ธีจันทร์มาตย์,บุญเลิศ ไชยพงษ์
# Name: 76, dtype: object)
# *********************************
# (77, title      อันนินทากาเลเหมือนเทน้ำ ไม่ชอกช้ำเหมือนมีดที่ก...
# type                                              นิทานชีวิต
# creator                                                  NaN
# Name: 77, dtype: object)
# *********************************
# (78, title          ทีใครทีมัน
# type           นิทานชีวิต
# creator    ทวี มุขธระโกษา
# Name: 78, dtype: object)
# *********************************
# (79, title      โลภมาก มักลาภหาย
# type         นิทานมหัศจรรย์
# creator      ทวี มุขธระโกษา
# Name: 79, dtype: object)
# *********************************
# (80, title      ตาดีกับยายดัน
# type          นิทานชีวิต
# creator    กฤชกร เพชรนอก
# Name: 80, dtype: object)
# *********************************
# (81, title             นายดัน
# type              มุขตลก
# creator    กฤชกร เพชรนอก
# Name: 81, dtype: object)
# *********************************
# (82, title            พญาหงส์
# type          นิทานสัตว์
# creator    กฤชกร เพชรนอก
# Name: 82, dtype: object)
# *********************************
# (83, title              กบกินเดือน
# type             ตำนานปรัมปรา
# creator    นิพัทธ์พร เพ็งแก้ว
# Name: 83, dtype: object)
# *********************************
# (84, title      ตำนานพระธาตุอรหันต์โมคคัลลาน์
# type                      นิทานประจำถิ่น
# creator            หลวงพ่อปลัดหล้า อินโท
# Name: 84, dtype: object)
# *********************************
# (85, title          รากไม้วิเศษ
# type        นิทานมหัศจรรย์
# creator    ทุเรียน บุญเลิศ
# Name: 85, dtype: object)
# *********************************
# (86, title      ศิษย์ไม่มีปัญญา
# type            นิทานชีวิต
# creator    ทุเรียน บุญเลิศ
# Name: 86, dtype: object)
# *********************************
# (87, title          ท่งป่ะหลาน
# type       นิทานประจำถิ่น
# creator      ตุ่น จันชื่น
# Name: 87, dtype: object)
# *********************************
# (88, title      ทุ่งกุลาฮ่องไห้
# type        นิทานประจำถิ่น
# creator                NaN
# Name: 88, dtype: object)
# *********************************
# (89, title           ย่ากินปลิง
# type            นิทานชีวิต
# creator    แช่ม วงศ์ประกอบ
# Name: 89, dtype: object)
# *********************************
# (90, title      หลวงพ่อกินขี้ไก่โป่
# type                    มุขตลก
# creator       สมศรี ถอนภูเขียว
# Name: 90, dtype: object)
# *********************************
# (91, title      หลวงพ่อม้าน้อยหลังแอ่น
# type                       มุขตลก
# creator              พรม วรรณศิริ
# Name: 91, dtype: object)
# *********************************
# (92, title            คนไหวพริบดี
# type                  มุขตลก
# creator    เหรียญ งวงชัยภูมิ
# Name: 92, dtype: object)
# *********************************
# (93, title      พ่อเฒ่ากับลูกเขยกินข้าวนำกัน
# type                             มุขตลก
# creator                  สุรพันธ์ บุญชู
# Name: 93, dtype: object)
# *********************************
# (94, title      ท้าวปาจิตนางอรพิม
# type          นิทานประจำถิ่น
# creator                  NaN
# Name: 94, dtype: object)
# *********************************
# (95, title      กำพร้าผีน้อย
# type            นิทานผี
# creator             NaN
# Name: 95, dtype: object)
# *********************************
# (96, title           นางหมาขาว
# type       นิทานมหัศจรรย์
# creator               NaN
# Name: 96, dtype: object)
# *********************************
# (97, title      พ่อใหญ่หัวล้าน
# type               มุขตลก
# creator     เลิศ ประนัดเด
# Name: 97, dtype: object)
# *********************************
# (98, title      หลวงพ่อกะทอเกลือ
# type                 มุขตลก
# creator       อาคม  ปาสานัย
# Name: 98, dtype: object)
# *********************************
# (99, title              เด็กโง่
# type                มุขตลก
# creator    เรียบ รักสมบัติ
# Name: 99, dtype: object)
# *********************************
# (100, title      ผีกองกอย
# type        นิทานผี
# creator         NaN
# Name: 100, dtype: object)
# *********************************
# (101, title      ปลาหมอตายเพราะปาก
# type              นิทานชีวิต
# creator       ทวี มุขธระโกษา
# Name: 101, dtype: object)
# *********************************
# (102, title            หมากับแมว
# type       นิทานอธิบายเหตุ
# creator      กฤชกร เพชรนอก
# Name: 102, dtype: object)
# *********************************
# (103, title             พรหนึ่งข้อ
# type          นิทานมหัศจรรย์
# creator    ซอย  รอยจันทร์ศรี
# Name: 103, dtype: object)
# *********************************
# (104, title            พญากินรำ
# type       นิทานมหัศจรรย์
# creator    สุนัญญา  มะลาด
# Name: 104, dtype: object)
# *********************************
# (105, title              น้ำใจคน
# type        นิทานประจำถิ่น
# creator    ศิริญภรณ์  โวลา
# Name: 105, dtype: object)
# *********************************
# (106, title             กากินบ้ง
# type       นิทานอธิบายเหตุ
# creator    มนูญ  อุตรินทร์
# Name: 106, dtype: object)
# *********************************
# (107, title              มะกอกทองคำ
# type           นิทานมหัศจรรย์
# creator    เพ็ญประภา  ทองเภ้า
# Name: 107, dtype: object)
# *********************************
# (108, title      เซียงเมี่ยงกับหอย
# type                  มุขตลก
# creator       สุนัญญา  มะลาด
# Name: 108, dtype: object)
# *********************************
# (109, title              นกนางแอ่น
# type              นิทานสัตว์
# creator    อังคาร กัลยาณพงศ์
# Name: 109, dtype: object)
# *********************************
# (110, title      ท้าวกำพร้าไก่แก้ว
# type          นิทานมหัศจรรย์
# creator                  NaN
# Name: 110, dtype: object)
# *********************************
# (111, title      กับแก้กับงูเขียว
# type         นิทานมหัศจรรย์
# creator      บุดดา ยืนชีวิต
# Name: 111, dtype: object)
# *********************************
# (112, title      ธุระไม่ใช่
# type       นิทานชีวิต
# creator           NaN
# Name: 112, dtype: object)
# *********************************
# (113, title      ทำไมเสือจึงมีลาย
# type        นิทานอธิบายเหตุ
# creator                 NaN
# Name: 113, dtype: object)
# *********************************
# (114, title            ตะเกียงวิเศษ
# type                   มุขตลก
# creator    สวาสดิ์ ท้าวอานนท์
# Name: 114, dtype: object)
# *********************************
# (115, title          แม่หม้ายตาโป
# type         นิทานมหัศจรรย์
# creator    อ่อนตา ประกาเวสา
# Name: 115, dtype: object)
# *********************************
# (116, title              วัวทรงพลัง
# type               นิทานชีวิต
# creator    อานุภาพ ปะจิตตังโข
# Name: 116, dtype: object)
# *********************************
# (117, title       ดาวลูกไก่
# type       นิทานชีวิต
# creator     วัชเรสรวง
# Name: 117, dtype: object)
# *********************************
# (118, title              ยักษ์เกเร
# type                  มุขตลก
# creator    พิสิฐ น้อยวังคลัง
# Name: 118, dtype: object)
# *********************************
# (119, title             ยายม่วง
# type               มุขตลก
# creator    กฤษฎา โยธายุทธ
# Name: 119, dtype: object)
# *********************************
# (120, title        ผีหลังกลวง
# type            นิทานผี
# creator    พิไล กล้าหาญ
# Name: 120, dtype: object)
# *********************************
# (121, title      สามสหายสามโรค
# type              มุขตลก
# creator              NaN
# Name: 121, dtype: object)
# *********************************
# (122, title      หนวกพึง
# type        มุขตลก
# creator        NaN
# Name: 122, dtype: object)
# *********************************
# (123, title      ไอ้ปั้นข้าวใหญ่
# type            นิทานชีวิต
# creator                NaN
# Name: 123, dtype: object)
# *********************************
# (124, title      ม้าตัวผู้ออกลูก
# type            นิทานชีวิต
# creator                NaN
# Name: 124, dtype: object)
# *********************************
# (125, title      สองสหายลักไก่
# type              มุขตลก
# creator              NaN
# Name: 125, dtype: object)
# *********************************
# (126, title      สามเกลอลักควาย
# type               มุขตลก
# creator               NaN
# Name: 126, dtype: object)
# *********************************
# (127, title      ผัวเป็นเพียเพราะเมียช่างพูด
# type                        นิทานชีวิต
# creator                            NaN
# Name: 127, dtype: object)
# *********************************
# (128, title          รักแท้
# type       นิทานชีวิต
# creator           NaN
# Name: 128, dtype: object)
# *********************************
# (129, title      ลูกสะใภ้เศรษฐี
# type           นิทานชีวิต
# creator               NaN
# Name: 129, dtype: object)
# *********************************
# (130, title       เอาน้ำลูบท้อง
# type               มุขตลก
# creator    ทวี มุขธระโกษา
# Name: 130, dtype: object)
# *********************************
# (131, title      ให้ทุกข์แก่ท่าน ทุกข์นั้นถึงตัว
# type                            นิทานชีวิต
# creator                     ทวี มุขธระโกษา
# Name: 131, dtype: object)
# *********************************
# (132, title      หนูตกถังข้าวสาร
# type                มุขตลก
# creator     ทวี มุขธระโกษา
# Name: 132, dtype: object)
# *********************************
# (133, title      คนเกียจคร้าน นานไปจะไร้ทรัพย์
# type                          นิทานชีวิต
# creator                   ทวี มุขธระโกษา
# Name: 133, dtype: object)
# *********************************
# (134, title         พญาฉัททันต์
# type           นิทานศาสนา
# creator    ทวี มุขธระโกษา
# Name: 134, dtype: object)
# *********************************
# (135, title              สุบิน
# type          นิทานศาสนา
# creator    กฤชกร เพชรนอก
# Name: 135, dtype: object)
# *********************************
# (136, title         ถ้ำตับเต่า
# type          นิทานศาสนา
# creator    กฤชกร เพชรนอก
# Name: 136, dtype: object)
# *********************************
# (137, title      จักจั่นไม่มีไส้
# type       นิทานอธิบายเหตุ
# creator                NaN
# Name: 137, dtype: object)
# *********************************
# (138, title      ซิ้นสองต่อน
# type        นิทานชีวิต
# creator            NaN
# Name: 138, dtype: object)
# *********************************
# (139, title      ขี้เหล้าเล่นหม้อ
# type             นิทานชีวิต
# creator                 NaN
# Name: 139, dtype: object)
# *********************************
# (140, title      ทำไมหมาไม่กินกุดจี่
# type           นิทานอธิบายเหตุ
# creator              วัน ทองคำ
# Name: 140, dtype: object)
# *********************************
# (141, title            หนองหล่ม
# type       นิทานประจำถิ่น
# creator               NaN
# Name: 141, dtype: object)
# *********************************
# (142, title      ผีกองกอย
# type        นิทานผี
# creator         NaN
# Name: 142, dtype: object)
# *********************************
# (143, title          ไอ้เจ็ดไห
# type       นิทานวีรบุรุษ
# creator              NaN
# Name: 143, dtype: object)
# *********************************
# (144, title       ปู่ปะหลาน
# type       นิทานชีวิต
# creator           NaN
# Name: 144, dtype: object)
# *********************************
# (145, title      เสือทำไมจึงตัวลาย
# type         นิทานอธิบายเหตุ
# creator         ตา นาคประสาท
# Name: 145, dtype: object)
# *********************************
# (146, title      ทำไมกากับนกยูงจึงเป็นศัตรูกัน
# type                     นิทานอธิบายเหตุ
# creator                              NaN
# Name: 146, dtype: object)
# *********************************
# (147, title      ทำไมงูเหลือมจึงไม่มีพิษ
# type               นิทานอธิบายเหตุ
# creator                        NaN
# Name: 147, dtype: object)
# *********************************
# (148, title      ลิงกับเต่า
# type       นิทานสัตว์
# creator           NaN
# Name: 148, dtype: object)
# *********************************
# (149, title           ปูทอง
# type       นิทานสัตว์
# creator           NaN
# Name: 149, dtype: object)
# *********************************
# (150, title      ศุภมิตร-เกศินี
# type           นิทานชีวิต
# creator               NaN
# Name: 150, dtype: object)
# *********************************
# (151, title      ท้าวเสียวสวาด
# type        นิทานเข้าแบบ
# creator              NaN
# Name: 151, dtype: object)
# *********************************
# (152, title          สุทธนูชาดก
# type       นิทานมหัศจรรย์
# creator               NaN
# Name: 152, dtype: object)
# *********************************
# (153, title      พื้นเวียงจันทร์
# type        นิทานประจำถิ่น
# creator                NaN
# Name: 153, dtype: object)
# *********************************
# (154, title             ลิ้นทอง
# type       นิทานมหัศจรรย์
# creator               NaN
# Name: 154, dtype: object)
# *********************************
# (155, title      แสงมณีแยงโลก
# type         นิทานศาสนา
# creator             NaN
# Name: 155, dtype: object)
# *********************************
# (156, title       พระปลาค่อ
# type       นิทานศาสนา
# creator           NaN
# Name: 156, dtype: object)
# *********************************
# (157, title              สินไซ
# type       นิทานวีรบุรุษ
# creator              NaN
# Name: 157, dtype: object)
# *********************************
# (158, title            มณีสัจจา
# type       นิทานมหัศจรรย์
# creator               NaN
# Name: 158, dtype: object)
# *********************************
# (159, title      สุปุณณานาคชาดก
# type           นิทานศาสนา
# creator               NaN
# Name: 159, dtype: object)
# *********************************
# (160, title      สุพรหมโมกขา
# type        นิทานศาสนา
# creator            NaN
# Name: 160, dtype: object)
# *********************************
# (161, title      อุปคุตผาบมาร
# type         นิทานศาสนา
# creator             NaN
# Name: 161, dtype: object)
# *********************************
# (162, title           อินทปัตถา
# type       นิทานมหัศจรรย์
# creator               NaN
# Name: 162, dtype: object)
# *********************************
# (163, title            สุริวงศ์
# type       นิทานมหัศจรรย์
# creator               NaN
# Name: 163, dtype: object)
# *********************************
# (164, title      หน้าผากไกลกระด้น
# type         นิทานมหัศจรรย์
# creator                 NaN
# Name: 164, dtype: object)
# *********************************
# (165, title      สุริยคราส – จันทคราส
# type             นิทานมหัศจรรย์
# creator                     NaN
# Name: 165, dtype: object)
# *********************************
# (166, title       ท้าวมูนกิตติ
# type       นิทานวีรบุรุษ
# creator              NaN
# Name: 166, dtype: object)
# *********************************
# (167, title      ตำนานเมืองฟ้าแดดสงยาง
# type              นิทานประจำถิ่น
# creator                      NaN
# Name: 167, dtype: object)
# *********************************
# (168, title            นางผมหอม
# type       นิทานประจำถิ่น
# creator               NaN
# Name: 168, dtype: object)
# *********************************
# (169, title          แก่งคุดคู้
# type       นิทานประจำถิ่น
# creator               NaN
# Name: 169, dtype: object)
# *********************************
# (170, title                นายแรง
# type         นิทานประจำถิ่น
# creator    สวัสดิ์  แก้วเศษ
# Name: 170, dtype: object)
# *********************************
# (171, title        เก่งไม่เท่ากัน
# type             นิทานชีวิต
# creator    ลาภ  เพ็ญสวัสดิ์
# Name: 171, dtype: object)
# *********************************
# (172, title       แก้วสารพัดนึก
# type       นิทานมหัศจรรย์
# creator      รุ่น  สมมาตร
# Name: 172, dtype: object)
# *********************************
# (173, title      คงรอดกับยอดทอง
# type           นิทานชีวิต
# creator               NaN
# Name: 173, dtype: object)
# *********************************
# (174, title             คนอยากรวย
# type             นิทานชีวิต
# creator    ลาภ  เพ็ญสวัสดิ์
# Name: 174, dtype: object)
# *********************************
# (175, title      ความลับไม่มีในโลก
# type         นิทานอธิบายเหตุ
# creator         รุ่น  สมมาตร
# Name: 175, dtype: object)
# *********************************
# (176, title        ช้างเกเร
# type       นิทานสัตว์
# creator           NaN
# Name: 176, dtype: object)
# *********************************
# (177, title          ชายพร้าแหว่ง
# type             นิทานชีวิต
# creator    ลาภ  เพ็ญสวัสดิ์
# Name: 177, dtype: object)
# *********************************
# (178, title          ชายผู้งมงาย
# type       นิทานอธิบายเหตุ
# creator    สมปอง  พัฒนพงศ์
# Name: 178, dtype: object)
# *********************************
# (179, title        ด้ามมีดพ่อท่าน
# type        นิทานอธิบายเหตุ
# creator    ลาภ  เพ็ญสวัสดิ์
# Name: 179, dtype: object)
# *********************************
# (180, title              นายพรานใจดี
# type           นิทานอธิบายเหตุ
# creator    สายัณห์  กุลสุวรรณ์
# Name: 180, dtype: object)
# *********************************
# (181, title        เป็นหมาดีที่สุด
# type              นิทานสัตว์
# creator    ทองแน่น เพชรสิงห์
# Name: 181, dtype: object)
# *********************************
# (182, title             ไอ้สองเกลอ
# type         นิทานอธิบายเหตุ
# creator    ทองแน่น เพชรสิงห์
# Name: 182, dtype: object)
# *********************************
# (183, title             นกบินหลา
# type       นิทานอธิบายเหตุ
# creator                NaN
# Name: 183, dtype: object)
# *********************************
# (184, title      คนเลี้ยงเป็ดเจ้าปัญญา
# type             นิทานอธิบายเหตุ
# creator                      NaN
# Name: 184, dtype: object)
# *********************************
# (185, title       งูเหลือมวิดปลา
# type       นิทานอธิบายเหตุ
# creator                NaN
# Name: 185, dtype: object)
# *********************************
# (186, title            เสือขอลูก
# type       นิทานอธิบายเหตุ
# creator         วิน  มีปิด
# Name: 186, dtype: object)
# *********************************
# (187, title      เหตุที่ปลาไหลตัวเล็ก
# type            นิทานอธิบายเหตุ
# creator       ทองแน่น เพชรสิงห์
# Name: 187, dtype: object)
# *********************************
# (188, title        พระเจ้าชัยชนะ
# type       นิทานอธิบายเหตุ
# creator     วัน  มรกตจันโส
# Name: 188, dtype: object)
# *********************************
# (189, title            พระคุณแม่โพสพ
# type           นิทานอธิบายเหตุ
# creator    นวลจันทร์  จีนเมือง
# Name: 189, dtype: object)
# *********************************
# (190, title      เหตุที่ลูกเต่าร้างคัน
# type             นิทานอธิบายเหตุ
# creator         ลาภ  เพ็ญสวัสดิ์
# Name: 190, dtype: object)
# *********************************
# (191, title         พระนางโภควดี
# type       นิทานอธิบายเหตุ
# creator    มิ่น  ปล้องใหม่
# Name: 191, dtype: object)
# *********************************
# (192, title        กรรมเก่าของกา
# type       นิทานอธิบายเหตุ
# creator                NaN
# Name: 192, dtype: object)
# *********************************
# (193, title       กระดูกไก่
# type       นิทานชีวิต
# creator           NaN
# Name: 193, dtype: object)
# *********************************
# (194, title      กระต่ายบนดวงจันทร์
# type             ตำนานปรัมปรา
# creator     เอื้อน ทรัพย์แก้ว
# Name: 194, dtype: object)
# *********************************
# (195, title            กล้วยสองปลี
# type              นิทานชีวิต
# creator    เคล้า  เลื่อนกฐิน
# Name: 195, dtype: object)
# *********************************
# (196, title      การแบ่งอายุของสัตว์
# type           นิทานอธิบายเหตุ
# creator      ปัญญา  พูลสวัสดิ์
# Name: 196, dtype: object)
# *********************************
# (197, title      การละอายความชั่ว
# type             นิทานชีวิต
# creator                 NaN
# Name: 197, dtype: object)
# *********************************
# (198, title            การเล่นจาโต
# type            ตำนานปรัมปรา
# creator    เอื้อน ทรัพย์แก้ว
# Name: 198, dtype: object)
# *********************************
# (199, title      กิน นอน โกหก
# type         นิทานชีวิต
# creator    คลิ้ง  คงบัว
# Name: 199, dtype: object)
# *********************************
# (200, title         เกาะสี่เกาะห้า
# type          นิทานประจำถิ่น
# creator    เอื้อน ทรัพย์แก้ว
# Name: 200, dtype: object)
# *********************************
# (201, title         เกาะหนูเกาะแมว
# type          นิทานประจำถิ่น
# creator    เอื้อน ทรัพย์แก้ว
# Name: 201, dtype: object)
# *********************************
# (202, title                คนทีดำ
# type         นิทานประจำถิ่น
# creator    แรม   เทพนุรักษ์
# Name: 202, dtype: object)
# *********************************
# (203, title               คนธรรพ์
# type         นิทานประจำถิ่น
# creator    แรม   เทพนุรักษ์
# Name: 203, dtype: object)
# *********************************
# (204, title         ปลาเงินปลาทอง
# type         นิทานประจำถิ่น
# creator    แรม   เทพนุรักษ์
# Name: 204, dtype: object)
# *********************************
# (205, title               เขาปู่เขาย่า
# type              นิทานประจำถิ่น
# creator    ต่วน   พงศ์วงประเสริฐ
# Name: 205, dtype: object)
# *********************************
# (206, title        คนพาซื่อ
# type       นิทานสัตว์
# creator           NaN
# Name: 206, dtype: object)
# *********************************
# (207, title                  เจ้าชายกบ
# type              นิทานมหัศจรรย์
# creator    ต่วน   พงศ์วงประเสริฐ
# Name: 207, dtype: object)
# *********************************
# (208, title                เจ้าชายปัญญา
# type                   นิทานชีวิต
# creator    หร้อหวาน   วัชรจิรโสภณ
# Name: 208, dtype: object)
# *********************************
# (209, title      ค่อยโถเอาใหม่
# type              มุขตลก
# creator              NaN
# Name: 209, dtype: object)
# *********************************
# (210, title         งูกายสิทธิ์
# type       นิทานมหัศจรรย์
# creator      สะ  นิยมเดชา
# Name: 210, dtype: object)
# *********************************
# (211, title        งูเหลือมคายพิษ
# type        นิทานอธิบายเหตุ
# creator    เลียบ  พรหมจรรย์
# Name: 211, dtype: object)
# *********************************
# (212, title        จระเข้กับจิ้งจก
# type         นิทานอธิบายเหตุ
# creator    เอื้อน ทรัพย์แก้ว
# Name: 212, dtype: object)
# *********************************
# (213, title      จอมคาถา
# type        มุขตลก
# creator        NaN
# Name: 213, dtype: object)
# *********************************
# (214, title      จังไรฉิบหาย
# type            มุขตลก
# creator            NaN
# Name: 214, dtype: object)
# *********************************
# (215, title      ไชชายนายปลอก
# type         นิทานชีวิต
# creator             NaN
# Name: 215, dtype: object)
# *********************************
# (216, title      ไชชายเลือกเมีย
# type           นิทานชีวิต
# creator     เพิ่ม พวงแก้ว
# Name: 216, dtype: object)
# *********************************
# (217, title               เณรทอง
# type        นิทานประจำถิ่น
# creator    รมย์   เผือกแสง
# Name: 217, dtype: object)
# *********************************
# (218, title      ดวงอาทิตย์กับไก่
# type        นิทานอธิบายเหตุ
# creator     รมย์   เผือกแสง
# Name: 218, dtype: object)
# *********************************
# (219, title      ต้นลำพูกับนิทานหิ่งห้อย
# type               นิทานอธิบายเหตุ
# creator             อารี  เส้งวั่น
# Name: 219, dtype: object)
# *********************************
# (220, title             ตาแขนปม
# type       นิทานมหัศจรรย์
# creator               NaN
# Name: 220, dtype: object)
# *********************************
# (221, title                 ตำนานมะโย่ง
# type                 ตำนานปรัมปรา
# creator    หร้อหวาน   วัชรจิรโสภณ
# Name: 221, dtype: object)
# *********************************
# (222, title             ตำราหมอดู
# type                 มุขตลก
# creator    มาลี   พันธ์วงศ์
# Name: 222, dtype: object)
# *********************************
# (223, title      เต่ากับพระพุทธเจ้า
# type          นิทานอธิบายเหตุ
# creator                   NaN
# Name: 223, dtype: object)
# *********************************
# (224, title       ถ้ำคูหาสวรรค์
# type       นิทานประจำถิ่น
# creator               NaN
# Name: 224, dtype: object)
# *********************************
# (225, title      ถ้ำทองและถ้ำเปอร์งง
# type            นิทานประจำถิ่น
# creator                    NaN
# Name: 225, dtype: object)
# *********************************

# %%
    for each_row in this_data.iterrows():
    # print(each_row)
    # print(each_row[1])
    if (each_row[1]['age'] == 20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น'):
        print(each_row)

# %% [markdown]
# # Quiz 9
#
# - วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง
#
# - มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน
#
# - คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่ หรือ พ่อ มากที่สุด

# %%
#วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง
for each_row in this_data.iterrows():
  if 'แม่' in each_row[1]['title'] or 'พ่อ' in each_row[1]['title']:
    print(each_row[1]['title'])
# Out:
# ก่องข้าวน้อยฆ่าแม่
# หลวงพ่อน้องงัว
# หลวงพ่อกับเณรน้อย
# แม่ใหญ่แฮก
# ปัญญาของพ่อ
# แม่เฒ่ากับลูกเขย
# หลวงพ่อกลัวผีหลอก
# หลวงพ่อเข้าลอดช่อง
# ลูกหลงพ่อ
# ก่องข้าวน้อยฆ่าแม่
# หลวงพ่อกับน้องงัว
# ก่องข้าวน้อยฆ่าแม่
# พ่อตากับลูกเขย ตอน ลูกเขยขายขี้
# พ่อตากับลูกเขยใหม่
# หลวงพ่ออยากกินจิ้งหรีด
# หลวงพ่อไม้ไผ่ หลวงพ่อมะเขือ
# คนจีนกับหลวงพ่อเจ้าอาวาส
# หลวงพ่อกินขี้ไก่โป่
# หลวงพ่อม้าน้อยหลังแอ่น
# พ่อเฒ่ากับลูกเขยกินข้าวนำกัน
# พ่อใหญ่หัวล้าน
# หลวงพ่อกะทอเกลือ
# แม่หม้ายตาโป
# ด้ามมีดพ่อท่าน
# พระคุณแม่โพสพ

# %%
#มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน
count_life = 0
count_province = 0
for each_row in this_data.iterrows():
  if 'ชีวิต' in each_row[1]['description']:
    count_life += 1
  if 'ประจำถิ่น' in each_row[1]['description']:
    count_province += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'description'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-8e1571d90186> in <cell line: 4>()
#       3 count_province = 0
#       4 for each_row in this_data.iterrows():
# ----> 5   if 'ชีวิต' in each_row[1]['description']:
#       6     count_life += 1
#       7   if 'ประจำถิ่น' in each_row[1]['description']:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'description'

# %%
#คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่ หรือ พ่อ มากที่สุด
for each_row in this_data.iterrows():
  if 'แม่' in each_row[1]['title'] or 'พ่อ' in each_row[1]['title']:
    print(each_row[1]['creator'])
# Out:
# หนูเวียง แก้วเวียง
# สุบิน คำยางจ้อง
# ปรางค์ทิพย์ บุญสีลา
# ชลิตา โพธิสาร
# ไพบูลย์ ระหา
# สุนีย์ คุณโพธิ์
# เสาร์ จันกอ
# เสาร์ จันกอ
# จันทร์ โพธิ์ไทสง
# หนูเวียง แก้วเวียง
# nan
# nan
# nan
# nan
# nan
# nan
# อ่อนตา ประกาเวสา
# สมศรี ถอนภูเขียว
# พรม วรรณศิริ
# สุรพันธ์ บุญชู
# เลิศ ประนัดเด
# อาคม  ปาสานัย
# อ่อนตา ประกาเวสา
# ลาภ  เพ็ญสวัสดิ์
# นวลจันทร์  จีนเมือง

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %%
for each_row in range(this_data.shape[0]):
    if (this_data.iloc[each_row,1] == 20) and (this_data.iloc[each_row,2] == 'ขอนแก่น'):  #each_row คือ ตัวเลข
        print(each_row)
        print(this_data.iloc[each_row,:])
# Out:
# 9334
# sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object

# %% [markdown]
# ## Quiz ตัดตารางออกมาเฉพาะปี 2021 ```announce_date``` ในปี 2021
#
# **Hint**
# *   วนลูปหา index ของปี 2021
# *   ตัดตารางมาเฉพาะ ปี 2021

# %%
TF=list()
for each_row in data_covid.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        TF.append(True)
    else:
        TF.append(False)

data_covid[TF].head()
# Out:
#        No.  ...                                               risk
# 6884  6885  ...                                  Cluster สมุทรสาคร
# 6885  6886  ...                                      Cluster ระยอง
# 6886  6887  ...                                        สถานบันเทิง
# 6887  6888  ...                                  Cluster สมุทรสาคร
# 6888  6889  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
#
# [5 rows x 10 columns]

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
data_covid.describe()
# Out:
#                 No.          age
# count  12653.000000  8881.000000
# mean    6327.000000    38.054748
# std     3652.750813    15.125178
# min        1.000000     0.100000
# 25%     3164.000000    27.000000
# 50%     6327.000000    36.000000
# 75%     9490.000000    48.000000
# max    12653.000000    97.000000

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
data_covid[data_covid['sex']=='ชาย']['age'].mean()
# Out:
# 39.46076940331987

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
